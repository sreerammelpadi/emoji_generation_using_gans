# %%
# !unzip smiley_ccr_128.zip
# Out:
# Archive:  smiley_ccr_128.zip
#    creating: resizeopenmoji128/
#   inflating: resizeopenmoji128/0023-FE0F-20E3.png
#   inflating: resizeopenmoji128/002A-FE0F-20E3.png
#   inflating: resizeopenmoji128/0030-FE0F-20E3.png
#   inflating: resizeopenmoji128/0031-FE0F-20E3.png
#   inflating: resizeopenmoji128/0032-FE0F-20E3.png
#   inflating: resizeopenmoji128/0033-FE0F-20E3.png
#   inflating: resizeopenmoji128/0034-FE0F-20E3.png
#   inflating: resizeopenmoji128/0035-FE0F-20E3.png
#   inflating: resizeopenmoji128/0036-FE0F-20E3.png
#   inflating: resizeopenmoji128/0037-FE0F-20E3.png
#   inflating: resizeopenmoji128/0038-FE0F-20E3.png
#   inflating: resizeopenmoji128/0039-FE0F-20E3.png
#   inflating: resizeopenmoji128/00A9.png
#   inflating: resizeopenmoji128/00AE.png
#   inflating: resizeopenmoji128/1F004.png
#   inflating: resizeopenmoji128/1F0CF.png
#   inflating: resizeopenmoji128/1F170.png
#   inflating: resizeopenmoji128/1F171.png
#   inflating: resizeopenmoji128/1F17E.png
#   inflating: resizeopenmoji128/1F17F.png
#   inflating: resizeopenmoji128/1F18E.png
#   inflating: resizeopenmoji128/1F191.png
#   inflating: resizeopenmoji128/1F192.png
#   inflating: resizeopenmoji128/1F193.png
#   inflating: resizeopenmoji128/1F194.png
#   inflating: resizeopenmoji128/1F195.png
#   inflating: resizeopenmoji128/1F196.png
#   inflating: resizeopenmoji128/1F197.png
#   inflating: resizeopenmoji128/1F198.png
#   inflating: resizeopenmoji128/1F199.png
#   inflating: resizeopenmoji128/1F19A.png
#   inflating: resizeopenmoji128/1F1E6-1F1E8.png
#   inflating: resizeopenmoji128/1F1E6-1F1E9.png
#   inflating: resizeopenmoji128/1F1E6-1F1EA.png
#   inflating: resizeopenmoji128/1F1E6-1F1EB.png
#   inflating: resizeopenmoji128/1F1E6-1F1EC.png
#   inflating: resizeopenmoji128/1F1E6-1F1EE.png
#   inflating: resizeopenmoji128/1F1E6-1F1F1.png
#   inflating: resizeopenmoji128/1F1E6-1F1F2.png
#   inflating: resizeopenmoji128/1F1E6-1F1F4.png
#   inflating: resizeopenmoji128/1F1E6-1F1F6.png
#   inflating: resizeopenmoji128/1F1E6-1F1F7.png
#   inflating: resizeopenmoji128/1F1E6-1F1F8.png
#   inflating: resizeopenmoji128/1F1E6-1F1F9.png
#   inflating: resizeopenmoji128/1F1E6-1F1FA.png
#   inflating: resizeopenmoji128/1F1E6-1F1FC.png
#   inflating: resizeopenmoji128/1F1E6-1F1FD.png
#   inflating: resizeopenmoji128/1F1E6-1F1FF.png
#   inflating: resizeopenmoji128/1F1E6.png
#   inflating: resizeopenmoji128/1F1E7-1F1E6.png
#   inflating: resizeopenmoji128/1F1E7-1F1E7.png
#   inflating: resizeopenmoji128/1F1E7-1F1E9.png
#   inflating: resizeopenmoji128/1F1E7-1F1EA.png
#   inflating: resizeopenmoji128/1F1E7-1F1EB.png
#   inflating: resizeopenmoji128/1F1E7-1F1EC.png
#   inflating: resizeopenmoji128/1F1E7-1F1ED.png
#   inflating: resizeopenmoji128/1F1E7-1F1EE.png
#   inflating: resizeopenmoji128/1F1E7-1F1EF.png
#   inflating: resizeopenmoji128/1F1E7-1F1F1.png
#   inflating: resizeopenmoji128/1F1E7-1F1F2.png
#   inflating: resizeopenmoji128/1F1E7-1F1F3.png
#   inflating: resizeopenmoji128/1F1E7-1F1F4.png
#   inflating: resizeopenmoji128/1F1E7-1F1F6.png
#   inflating: resizeopenmoji128/1F1E7-1F1F7.png
#   inflating: resizeopenmoji128/1F1E7-1F1F8.png
#   inflating: resizeopenmoji128/1F1E7-1F1F9.png
#   inflating: resizeopenmoji128/1F1E7-1F1FB.png
#   inflating: resizeopenmoji128/1F1E7-1F1FC.png
#   inflating: resizeopenmoji128/1F1E7-1F1FE.png
#   inflating: resizeopenmoji128/1F1E7-1F1FF.png
#   inflating: resizeopenmoji128/1F1E7.png
#   inflating: resizeopenmoji128/1F1E8-1F1E6.png
#   inflating: resizeopenmoji128/1F1E8-1F1E8.png
#   inflating: resizeopenmoji128/1F1E8-1F1E9.png
#   inflating: resizeopenmoji128/1F1E8-1F1EB.png
#   inflating: resizeopenmoji128/1F1E8-1F1EC.png
#   inflating: resizeopenmoji128/1F1E8-1F1ED.png
#   inflating: resizeopenmoji128/1F1E8-1F1EE.png
#   inflating: resizeopenmoji128/1F1E8-1F1F0.png
#   inflating: resizeopenmoji128/1F1E8-1F1F1.png
#   inflating: resizeopenmoji128/1F1E8-1F1F2.png
#   inflating: resizeopenmoji128/1F1E8-1F1F3.png
#   inflating: resizeopenmoji128/1F1E8-1F1F4.png
#   inflating: resizeopenmoji128/1F1E8-1F1F5.png
#   inflating: resizeopenmoji128/1F1E8-1F1F7.png
#   inflating: resizeopenmoji128/1F1E8-1F1FA.png
#   inflating: resizeopenmoji128/1F1E8-1F1FB.png
#   inflating: resizeopenmoji128/1F1E8-1F1FC.png
#   inflating: resizeopenmoji128/1F1E8-1F1FD.png
#   inflating: resizeopenmoji128/1F1E8-1F1FE.png
#   inflating: resizeopenmoji128/1F1E8-1F1FF.png
#   inflating: resizeopenmoji128/1F1E8.png
#   inflating: resizeopenmoji128/1F1E9-1F1EA.png
#   inflating: resizeopenmoji128/1F1E9-1F1EC.png
#   inflating: resizeopenmoji128/1F1E9-1F1EF.png
#   inflating: resizeopenmoji128/1F1E9-1F1F0.png
#   inflating: resizeopenmoji128/1F1E9-1F1F2.png
#   inflating: resizeopenmoji128/1F1E9-1F1F4.png
#   inflating: resizeopenmoji128/1F1E9-1F1FF.png
#   inflating: resizeopenmoji128/1F1E9.png
#   inflating: resizeopenmoji128/1F1EA-1F1E6.png
#   inflating: resizeopenmoji128/1F1EA-1F1E8.png
#   inflating: resizeopenmoji128/1F1EA-1F1EA.png
#   inflating: resizeopenmoji128/1F1EA-1F1EC.png
#   inflating: resizeopenmoji128/1F1EA-1F1ED.png
#   inflating: resizeopenmoji128/1F1EA-1F1F7.png
#   inflating: resizeopenmoji128/1F1EA-1F1F8.png
#   inflating: resizeopenmoji128/1F1EA-1F1F9.png
#   inflating: resizeopenmoji128/1F1EA-1F1FA.png
#   inflating: resizeopenmoji128/1F1EA.png
#   inflating: resizeopenmoji128/1F1EB-1F1EE.png
#   inflating: resizeopenmoji128/1F1EB-1F1EF.png
#   inflating: resizeopenmoji128/1F1EB-1F1F0.png
#   inflating: resizeopenmoji128/1F1EB-1F1F2.png
#   inflating: resizeopenmoji128/1F1EB-1F1F4.png
#   inflating: resizeopenmoji128/1F1EB-1F1F7.png
#   inflating: resizeopenmoji128/1F1EB.png
#   inflating: resizeopenmoji128/1F1EC-1F1E6.png
#   inflating: resizeopenmoji128/1F1EC-1F1E7.png
#   inflating: resizeopenmoji128/1F1EC-1F1E9.png
#   inflating: resizeopenmoji128/1F1EC-1F1EA.png
#   inflating: resizeopenmoji128/1F1EC-1F1EB.png
#   inflating: resizeopenmoji128/1F1EC-1F1EC.png
#   inflating: resizeopenmoji128/1F1EC-1F1ED.png
#   inflating: resizeopenmoji128/1F1EC-1F1EE.png
#   inflating: resizeopenmoji128/1F1EC-1F1F1.png
#   inflating: resizeopenmoji128/1F1EC-1F1F2.png
#   inflating: resizeopenmoji128/1F1EC-1F1F3.png
#   inflating: resizeopenmoji128/1F1EC-1F1F5.png
#   inflating: resizeopenmoji128/1F1EC-1F1F6.png
#   inflating: resizeopenmoji128/1F1EC-1F1F7.png
#   inflating: resizeopenmoji128/1F1EC-1F1F8.png
#   inflating: resizeopenmoji128/1F1EC-1F1F9.png
#   inflating: resizeopenmoji128/1F1EC-1F1FA.png
#   inflating: resizeopenmoji128/1F1EC-1F1FC.png
#   inflating: resizeopenmoji128/1F1EC-1F1FE.png
#   inflating: resizeopenmoji128/1F1EC.png
#   inflating: resizeopenmoji128/1F1ED-1F1F0.png
#   inflating: resizeopenmoji128/1F1ED-1F1F2.png
#   inflating: resizeopenmoji128/1F1ED-1F1F3.png
#   inflating: resizeopenmoji128/1F1ED-1F1F7.png
#   inflating: resizeopenmoji128/1F1ED-1F1F9.png
#   inflating: resizeopenmoji128/1F1ED-1F1FA.png
#   inflating: resizeopenmoji128/1F1ED.png
#   inflating: resizeopenmoji128/1F1EE-1F1E8.png
#   inflating: resizeopenmoji128/1F1EE-1F1E9.png
#   inflating: resizeopenmoji128/1F1EE-1F1EA.png
#   inflating: resizeopenmoji128/1F1EE-1F1F1.png
#   inflating: resizeopenmoji128/1F1EE-1F1F2.png
#   inflating: resizeopenmoji128/1F1EE-1F1F3.png
#   inflating: resizeopenmoji128/1F1EE-1F1F4.png
#   inflating: resizeopenmoji128/1F1EE-1F1F6.png
#   inflating: resizeopenmoji128/1F1EE-1F1F7.png
#   inflating: resizeopenmoji128/1F1EE-1F1F8.png
#   inflating: resizeopenmoji128/1F1EE-1F1F9.png
#   inflating: resizeopenmoji128/1F1EE.png
#   inflating: resizeopenmoji128/1F1EF-1F1EA.png
#   inflating: resizeopenmoji128/1F1EF-1F1F2.png
#   inflating: resizeopenmoji128/1F1EF-1F1F4.png
#   inflating: resizeopenmoji128/1F1EF-1F1F5.png
#   inflating: resizeopenmoji128/1F1EF.png
#   inflating: resizeopenmoji128/1F1F0-1F1EA.png
#   inflating: resizeopenmoji128/1F1F0-1F1EC.png
#   inflating: resizeopenmoji128/1F1F0-1F1ED.png
#   inflating: resizeopenmoji128/1F1F0-1F1EE.png
#   inflating: resizeopenmoji128/1F1F0-1F1F2.png
#   inflating: resizeopenmoji128/1F1F0-1F1F3.png
#   inflating: resizeopenmoji128/1F1F0-1F1F5.png
#   inflating: resizeopenmoji128/1F1F0-1F1F7.png
#   inflating: resizeopenmoji128/1F1F0-1F1FC.png
#   inflating: resizeopenmoji128/1F1F0-1F1FE.png
#   inflating: resizeopenmoji128/1F1F0-1F1FF.png
#   inflating: resizeopenmoji128/1F1F0.png
#   inflating: resizeopenmoji128/1F1F1-1F1E6.png
#   inflating: resizeopenmoji128/1F1F1-1F1E7.png
#   inflating: resizeopenmoji128/1F1F1-1F1E8.png
#   inflating: resizeopenmoji128/1F1F1-1F1EE.png
#   inflating: resizeopenmoji128/1F1F1-1F1F0.png
#   inflating: resizeopenmoji128/1F1F1-1F1F7.png
#   inflating: resizeopenmoji128/1F1F1-1F1F8.png
#   inflating: resizeopenmoji128/1F1F1-1F1F9.png
#   inflating: resizeopenmoji128/1F1F1-1F1FA.png
#   inflating: resizeopenmoji128/1F1F1-1F1FB.png
#   inflating: resizeopenmoji128/1F1F1-1F1FE.png
#   inflating: resizeopenmoji128/1F1F1.png
#   inflating: resizeopenmoji128/1F1F2-1F1E6.png
#   inflating: resizeopenmoji128/1F1F2-1F1E8.png
#   inflating: resizeopenmoji128/1F1F2-1F1E9.png
#   inflating: resizeopenmoji128/1F1F2-1F1EA.png
#   inflating: resizeopenmoji128/1F1F2-1F1EB.png
#   inflating: resizeopenmoji128/1F1F2-1F1EC.png
#   inflating: resizeopenmoji128/1F1F2-1F1ED.png
#   inflating: resizeopenmoji128/1F1F2-1F1F0.png
#   inflating: resizeopenmoji128/1F1F2-1F1F1.png
#   inflating: resizeopenmoji128/1F1F2-1F1F2.png
#   inflating: resizeopenmoji128/1F1F2-1F1F3.png
#   inflating: resizeopenmoji128/1F1F2-1F1F4.png
#   inflating: resizeopenmoji128/1F1F2-1F1F5.png
#   inflating: resizeopenmoji128/1F1F2-1F1F6.png
#   inflating: resizeopenmoji128/1F1F2-1F1F7.png
#   inflating: resizeopenmoji128/1F1F2-1F1F8.png
#   inflating: resizeopenmoji128/1F1F2-1F1F9.png
#   inflating: resizeopenmoji128/1F1F2-1F1FA.png
#   inflating: resizeopenmoji128/1F1F2-1F1FB.png
#   inflating: resizeopenmoji128/1F1F2-1F1FC.png
#   inflating: resizeopenmoji128/1F1F2-1F1FD.png
#   inflating: resizeopenmoji128/1F1F2-1F1FE.png
#   inflating: resizeopenmoji128/1F1F2-1F1FF.png
#   inflating: resizeopenmoji128/1F1F2.png
#   inflating: resizeopenmoji128/1F1F3-1F1E6.png
#   inflating: resizeopenmoji128/1F1F3-1F1E8.png
#   inflating: resizeopenmoji128/1F1F3-1F1EA.png
#   inflating: resizeopenmoji128/1F1F3-1F1EB.png
#   inflating: resizeopenmoji128/1F1F3-1F1EC.png
#   inflating: resizeopenmoji128/1F1F3-1F1EE.png
#   inflating: resizeopenmoji128/1F1F3-1F1F1.png
#   inflating: resizeopenmoji128/1F1F3-1F1F4.png
#   inflating: resizeopenmoji128/1F1F3-1F1F5.png
#   inflating: resizeopenmoji128/1F1F3-1F1F7.png
#   inflating: resizeopenmoji128/1F1F3-1F1FA.png
#   inflating: resizeopenmoji128/1F1F3-1F1FF.png
#   inflating: resizeopenmoji128/1F1F3.png
#   inflating: resizeopenmoji128/1F1F4-1F1F2.png
#   inflating: resizeopenmoji128/1F1F4.png
#   inflating: resizeopenmoji128/1F1F5-1F1E6.png
#   inflating: resizeopenmoji128/1F1F5-1F1EA.png
#   inflating: resizeopenmoji128/1F1F5-1F1EB.png
#   inflating: resizeopenmoji128/1F1F5-1F1EC.png
#   inflating: resizeopenmoji128/1F1F5-1F1ED.png
#   inflating: resizeopenmoji128/1F1F5-1F1F0.png
#   inflating: resizeopenmoji128/1F1F5-1F1F1.png
#   inflating: resizeopenmoji128/1F1F5-1F1F2.png
#   inflating: resizeopenmoji128/1F1F5-1F1F3.png
#   inflating: resizeopenmoji128/1F1F5-1F1F7.png
#   inflating: resizeopenmoji128/1F1F5-1F1F8.png
#   inflating: resizeopenmoji128/1F1F5-1F1F9.png
#   inflating: resizeopenmoji128/1F1F5-1F1FC.png
#   inflating: resizeopenmoji128/1F1F5-1F1FE.png
#   inflating: resizeopenmoji128/1F1F5.png
#   inflating: resizeopenmoji128/1F1F6-1F1E6.png
#   inflating: resizeopenmoji128/1F1F6.png
#   inflating: resizeopenmoji128/1F1F7-1F1EA.png
#   inflating: resizeopenmoji128/1F1F7-1F1F4.png
#   inflating: resizeopenmoji128/1F1F7-1F1F8.png
#   inflating: resizeopenmoji128/1F1F7-1F1FA.png
#   inflating: resizeopenmoji128/1F1F7-1F1FC.png
#   inflating: resizeopenmoji128/1F1F7.png
#   inflating: resizeopenmoji128/1F1F8-1F1E6.png
#   inflating: resizeopenmoji128/1F1F8-1F1E7.png
#   inflating: resizeopenmoji128/1F1F8-1F1E8.png
#   inflating: resizeopenmoji128/1F1F8-1F1E9.png
#   inflating: resizeopenmoji128/1F1F8-1F1EA.png
#   inflating: resizeopenmoji128/1F1F8-1F1EC.png
#   inflating: resizeopenmoji128/1F1F8-1F1ED.png
#   inflating: resizeopenmoji128/1F1F8-1F1EE.png
#   inflating: resizeopenmoji128/1F1F8-1F1EF.png
#   inflating: resizeopenmoji128/1F1F8-1F1F0.png
#   inflating: resizeopenmoji128/1F1F8-1F1F1.png
#   inflating: resizeopenmoji128/1F1F8-1F1F2.png
#   inflating: resizeopenmoji128/1F1F8-1F1F3.png
#   inflating: resizeopenmoji128/1F1F8-1F1F4.png
#   inflating: resizeopenmoji128/1F1F8-1F1F7.png
#   inflating: resizeopenmoji128/1F1F8-1F1F8.png
#   inflating: resizeopenmoji128/1F1F8-1F1F9.png
#   inflating: resizeopenmoji128/1F1F8-1F1FB.png
#   inflating: resizeopenmoji128/1F1F8-1F1FD.png
#   inflating: resizeopenmoji128/1F1F8-1F1FE.png
#   inflating: resizeopenmoji128/1F1F8-1F1FF.png
#   inflating: resizeopenmoji128/1F1F8.png
#   inflating: resizeopenmoji128/1F1F9-1F1E6.png
#   inflating: resizeopenmoji128/1F1F9-1F1E8.png
#   inflating: resizeopenmoji128/1F1F9-1F1E9.png
#   inflating: resizeopenmoji128/1F1F9-1F1EB.png
#   inflating: resizeopenmoji128/1F1F9-1F1EC.png
#   inflating: resizeopenmoji128/1F1F9-1F1ED.png
#   inflating: resizeopenmoji128/1F1F9-1F1EF.png
#   inflating: resizeopenmoji128/1F1F9-1F1F0.png
#   inflating: resizeopenmoji128/1F1F9-1F1F1.png
#   inflating: resizeopenmoji128/1F1F9-1F1F2.png
#   inflating: resizeopenmoji128/1F1F9-1F1F3.png
#   inflating: resizeopenmoji128/1F1F9-1F1F4.png
#   inflating: resizeopenmoji128/1F1F9-1F1F7.png
#   inflating: resizeopenmoji128/1F1F9-1F1F9.png
#   inflating: resizeopenmoji128/1F1F9-1F1FB.png
#   inflating: resizeopenmoji128/1F1F9-1F1FC.png
#   inflating: resizeopenmoji128/1F1F9-1F1FF.png
#   inflating: resizeopenmoji128/1F1F9.png
#   inflating: resizeopenmoji128/1F1FA-1F1E6.png
#   inflating: resizeopenmoji128/1F1FA-1F1EC.png
#   inflating: resizeopenmoji128/1F1FA-1F1F2.png
#   inflating: resizeopenmoji128/1F1FA-1F1F3.png
#   inflating: resizeopenmoji128/1F1FA-1F1F8.png
#   inflating: resizeopenmoji128/1F1FA-1F1FE.png
#   inflating: resizeopenmoji128/1F1FA-1F1FF.png
#   inflating: resizeopenmoji128/1F1FA.png
#   inflating: resizeopenmoji128/1F1FB-1F1E6.png
#   inflating: resizeopenmoji128/1F1FB-1F1E8.png
#   inflating: resizeopenmoji128/1F1FB-1F1EA.png
#   inflating: resizeopenmoji128/1F1FB-1F1EC.png
#   inflating: resizeopenmoji128/1F1FB-1F1EE.png
#   inflating: resizeopenmoji128/1F1FB-1F1F3.png
#   inflating: resizeopenmoji128/1F1FB-1F1FA.png
#   inflating: resizeopenmoji128/1F1FB.png
#   inflating: resizeopenmoji128/1F1FC-1F1EB.png
#   inflating: resizeopenmoji128/1F1FC-1F1F8.png
#   inflating: resizeopenmoji128/1F1FC.png
#   inflating: resizeopenmoji128/1F1FD-1F1F0.png
#   inflating: resizeopenmoji128/1F1FD.png
#   inflating: resizeopenmoji128/1F1FE-1F1EA.png
#   inflating: resizeopenmoji128/1F1FE-1F1F9.png
#   inflating: resizeopenmoji128/1F1FE.png
#   inflating: resizeopenmoji128/1F1FF-1F1E6.png
#   inflating: resizeopenmoji128/1F1FF-1F1F2.png
#   inflating: resizeopenmoji128/1F1FF-1F1FC.png
#   inflating: resizeopenmoji128/1F1FF.png
#   inflating: resizeopenmoji128/1F201.png
#   inflating: resizeopenmoji128/1F202.png
#   inflating: resizeopenmoji128/1F21A.png
#   inflating: resizeopenmoji128/1F22F.png
#   inflating: resizeopenmoji128/1F232.png
#   inflating: resizeopenmoji128/1F233.png
#   inflating: resizeopenmoji128/1F234.png
#   inflating: resizeopenmoji128/1F235.png
#   inflating: resizeopenmoji128/1F236.png
#   inflating: resizeopenmoji128/1F237.png
#   inflating: resizeopenmoji128/1F238.png
#   inflating: resizeopenmoji128/1F239.png
#   inflating: resizeopenmoji128/1F23A.png
#   inflating: resizeopenmoji128/1F250.png
#   inflating: resizeopenmoji128/1F251.png
#   inflating: resizeopenmoji128/1F300.png
#   inflating: resizeopenmoji128/1F301.png
#   inflating: resizeopenmoji128/1F302.png
#   inflating: resizeopenmoji128/1F303.png
#   inflating: resizeopenmoji128/1F304.png
#   inflating: resizeopenmoji128/1F305.png
#   inflating: resizeopenmoji128/1F306.png
#   inflating: resizeopenmoji128/1F307.png
#   inflating: resizeopenmoji128/1F308.png
#   inflating: resizeopenmoji128/1F309.png
#   inflating: resizeopenmoji128/1F30A.png
#   inflating: resizeopenmoji128/1F30B.png
#   inflating: resizeopenmoji128/1F30C.png
#   inflating: resizeopenmoji128/1F30D.png
#   inflating: resizeopenmoji128/1F30E.png
#   inflating: resizeopenmoji128/1F30F.png
#   inflating: resizeopenmoji128/1F310.png
#   inflating: resizeopenmoji128/1F311.png
#   inflating: resizeopenmoji128/1F312.png
#   inflating: resizeopenmoji128/1F313.png
#   inflating: resizeopenmoji128/1F314.png
#   inflating: resizeopenmoji128/1F315.png
#   inflating: resizeopenmoji128/1F316.png
#   inflating: resizeopenmoji128/1F317.png
#   inflating: resizeopenmoji128/1F318.png
#   inflating: resizeopenmoji128/1F319.png
#   inflating: resizeopenmoji128/1F31A.png
#  extracting: resizeopenmoji128/1F31B.png
#  extracting: resizeopenmoji128/1F31C.png
#   inflating: resizeopenmoji128/1F31D.png
#   inflating: resizeopenmoji128/1F31E.png
#   inflating: resizeopenmoji128/1F31F.png
#   inflating: resizeopenmoji128/1F320.png
#   inflating: resizeopenmoji128/1F321.png
#   inflating: resizeopenmoji128/1F324.png
#   inflating: resizeopenmoji128/1F325.png
#  extracting: resizeopenmoji128/1F326.png
#   inflating: resizeopenmoji128/1F327.png
#   inflating: resizeopenmoji128/1F328.png
#   inflating: resizeopenmoji128/1F329.png
#   inflating: resizeopenmoji128/1F32A.png
#   inflating: resizeopenmoji128/1F32B.png
#   inflating: resizeopenmoji128/1F32C.png
#   inflating: resizeopenmoji128/1F32D.png
#   inflating: resizeopenmoji128/1F32E.png
#   inflating: resizeopenmoji128/1F32F.png
#   inflating: resizeopenmoji128/1F330.png
#   inflating: resizeopenmoji128/1F331.png
#   inflating: resizeopenmoji128/1F332.png
#   inflating: resizeopenmoji128/1F333.png
#   inflating: resizeopenmoji128/1F334.png
#   inflating: resizeopenmoji128/1F335.png
#   inflating: resizeopenmoji128/1F336.png
#   inflating: resizeopenmoji128/1F337.png
#   inflating: resizeopenmoji128/1F338.png
#   inflating: resizeopenmoji128/1F339.png
#   inflating: resizeopenmoji128/1F33A.png
#   inflating: resizeopenmoji128/1F33B.png
#   inflating: resizeopenmoji128/1F33C.png
#   inflating: resizeopenmoji128/1F33D.png
#   inflating: resizeopenmoji128/1F33E.png
#   inflating: resizeopenmoji128/1F33F.png
#   inflating: resizeopenmoji128/1F340.png
#   inflating: resizeopenmoji128/1F341.png
#   inflating: resizeopenmoji128/1F342.png
#   inflating: resizeopenmoji128/1F343.png
#   inflating: resizeopenmoji128/1F344-200D-1F7EB.png
#   inflating: resizeopenmoji128/1F344.png
#   inflating: resizeopenmoji128/1F345.png
#   inflating: resizeopenmoji128/1F346.png
#   inflating: resizeopenmoji128/1F347.png
#   inflating: resizeopenmoji128/1F348.png
#   inflating: resizeopenmoji128/1F349.png
#   inflating: resizeopenmoji128/1F34A.png
#   inflating: resizeopenmoji128/1F34B-200D-1F7E9.png
#   inflating: resizeopenmoji128/1F34B.png
#   inflating: resizeopenmoji128/1F34C.png
#   inflating: resizeopenmoji128/1F34D.png
#   inflating: resizeopenmoji128/1F34E.png
#   inflating: resizeopenmoji128/1F34F.png
#   inflating: resizeopenmoji128/1F350.png
#   inflating: resizeopenmoji128/1F351.png
#   inflating: resizeopenmoji128/1F352.png
#   inflating: resizeopenmoji128/1F353.png
#   inflating: resizeopenmoji128/1F354.png
#   inflating: resizeopenmoji128/1F355.png
#   inflating: resizeopenmoji128/1F356.png
#   inflating: resizeopenmoji128/1F357.png
#   inflating: resizeopenmoji128/1F358.png
#   inflating: resizeopenmoji128/1F359.png
#   inflating: resizeopenmoji128/1F35A.png
#   inflating: resizeopenmoji128/1F35B.png
#   inflating: resizeopenmoji128/1F35C.png
#   inflating: resizeopenmoji128/1F35D.png
#   inflating: resizeopenmoji128/1F35E.png
#   inflating: resizeopenmoji128/1F35F.png
#   inflating: resizeopenmoji128/1F360.png
#   inflating: resizeopenmoji128/1F361.png
#   inflating: resizeopenmoji128/1F362.png
#   inflating: resizeopenmoji128/1F363.png
#   inflating: resizeopenmoji128/1F364.png
#   inflating: resizeopenmoji128/1F365.png
#   inflating: resizeopenmoji128/1F366.png
#   inflating: resizeopenmoji128/1F367.png
#   inflating: resizeopenmoji128/1F368.png
#   inflating: resizeopenmoji128/1F369.png
#   inflating: resizeopenmoji128/1F36A.png
#   inflating: resizeopenmoji128/1F36B.png
#   inflating: resizeopenmoji128/1F36C.png
#   inflating: resizeopenmoji128/1F36D.png
#   inflating: resizeopenmoji128/1F36E.png
#   inflating: resizeopenmoji128/1F36F.png
#   inflating: resizeopenmoji128/1F370.png
#   inflating: resizeopenmoji128/1F371.png
#   inflating: resizeopenmoji128/1F372.png
#   inflating: resizeopenmoji128/1F373.png
#   inflating: resizeopenmoji128/1F374.png
#   inflating: resizeopenmoji128/1F375.png
#   inflating: resizeopenmoji128/1F376.png
#   inflating: resizeopenmoji128/1F377.png
#   inflating: resizeopenmoji128/1F378.png
#   inflating: resizeopenmoji128/1F379.png
#   inflating: resizeopenmoji128/1F37A.png
#   inflating: resizeopenmoji128/1F37B.png
#   inflating: resizeopenmoji128/1F37C.png
#   inflating: resizeopenmoji128/1F37D.png
#   inflating: resizeopenmoji128/1F37E.png
#   inflating: resizeopenmoji128/1F37F.png
#   inflating: resizeopenmoji128/1F380.png
#   inflating: resizeopenmoji128/1F381.png
#   inflating: resizeopenmoji128/1F382.png
#   inflating: resizeopenmoji128/1F383.png
#   inflating: resizeopenmoji128/1F384.png
#   inflating: resizeopenmoji128/1F385.png
#   inflating: resizeopenmoji128/1F386.png
#   inflating: resizeopenmoji128/1F387.png
#   inflating: resizeopenmoji128/1F388.png
#   inflating: resizeopenmoji128/1F389.png
#   inflating: resizeopenmoji128/1F38A.png
#   inflating: resizeopenmoji128/1F38B.png
#   inflating: resizeopenmoji128/1F38C.png
#   inflating: resizeopenmoji128/1F38D.png
#   inflating: resizeopenmoji128/1F38E.png
#   inflating: resizeopenmoji128/1F38F.png
#   inflating: resizeopenmoji128/1F390.png
#   inflating: resizeopenmoji128/1F391.png
#   inflating: resizeopenmoji128/1F392.png
#   inflating: resizeopenmoji128/1F393.png
#   inflating: resizeopenmoji128/1F396.png
#   inflating: resizeopenmoji128/1F397.png
#   inflating: resizeopenmoji128/1F399.png
#   inflating: resizeopenmoji128/1F39A.png
#   inflating: resizeopenmoji128/1F39B.png
#   inflating: resizeopenmoji128/1F39E.png
#   inflating: resizeopenmoji128/1F39F.png
#   inflating: resizeopenmoji128/1F3A0.png
#   inflating: resizeopenmoji128/1F3A1.png
#   inflating: resizeopenmoji128/1F3A2.png
#   inflating: resizeopenmoji128/1F3A3.png
#   inflating: resizeopenmoji128/1F3A4.png
#   inflating: resizeopenmoji128/1F3A5.png
#   inflating: resizeopenmoji128/1F3A6.png
#   inflating: resizeopenmoji128/1F3A7.png
#   inflating: resizeopenmoji128/1F3A8.png
#   inflating: resizeopenmoji128/1F3A9.png
#   inflating: resizeopenmoji128/1F3AA.png
#   inflating: resizeopenmoji128/1F3AB.png
#   inflating: resizeopenmoji128/1F3AC.png
#   inflating: resizeopenmoji128/1F3AD.png
#   inflating: resizeopenmoji128/1F3AE.png
#   inflating: resizeopenmoji128/1F3AF.png
#   inflating: resizeopenmoji128/1F3B0.png
#   inflating: resizeopenmoji128/1F3B1.png
#   inflating: resizeopenmoji128/1F3B2.png
#   inflating: resizeopenmoji128/1F3B3.png
#   inflating: resizeopenmoji128/1F3B4.png
#   inflating: resizeopenmoji128/1F3B5.png
#   inflating: resizeopenmoji128/1F3B6.png
#   inflating: resizeopenmoji128/1F3B7.png
#   inflating: resizeopenmoji128/1F3B8.png
#   inflating: resizeopenmoji128/1F3B9.png
#   inflating: resizeopenmoji128/1F3BA.png
#   inflating: resizeopenmoji128/1F3BB.png
#   inflating: resizeopenmoji128/1F3BC.png
#   inflating: resizeopenmoji128/1F3BD.png
#   inflating: resizeopenmoji128/1F3BE.png
#   inflating: resizeopenmoji128/1F3BF.png
#   inflating: resizeopenmoji128/1F3C0.png
#   inflating: resizeopenmoji128/1F3C1.png
#   inflating: resizeopenmoji128/1F3C2.png
#   inflating: resizeopenmoji128/1F3C3-200D-2640-FE0F-200D-27A1-FE0F.png
#   inflating: resizeopenmoji128/1F3C3-200D-2640-FE0F.png
#   inflating: resizeopenmoji128/1F3C3-200D-2642-FE0F-200D-27A1-FE0F.png
#   inflating: resizeopenmoji128/1F3C3-200D-2642-FE0F.png
#   inflating: resizeopenmoji128/1F3C3-200D-27A1-FE0F.png
#   inflating: resizeopenmoji128/1F3C3.png
#   inflating: resizeopenmoji128/1F3C4-200D-2640-FE0F.png
#   inflating: resizeopenmoji128/1F3C4-200D-2642-FE0F.png
#   inflating: resizeopenmoji128/1F3C4.png
#   inflating: resizeopenmoji128/1F3C5.png
#   inflating: resizeopenmoji128/1F3C6.png
#   inflating: resizeopenmoji128/1F3C7.png
#   inflating: resizeopenmoji128/1F3C8.png
#   inflating: resizeopenmoji128/1F3C9.png
#   inflating: resizeopenmoji128/1F3CA-200D-2640-FE0F.png
#   inflating: resizeopenmoji128/1F3CA-200D-2642-FE0F.png
#   inflating: resizeopenmoji128/1F3CA.png
#   inflating: resizeopenmoji128/1F3CB-FE0F-200D-2640-FE0F.png
#   inflating: resizeopenmoji128/1F3CB-FE0F-200D-2642-FE0F.png
#   inflating: resizeopenmoji128/1F3CB.png
#   inflating: resizeopenmoji128/1F3CC-FE0F-200D-2640-FE0F.png
#   inflating: resizeopenmoji128/1F3CC-FE0F-200D-2642-FE0F.png
#   inflating: resizeopenmoji128/1F3CC.png
#   inflating: resizeopenmoji128/1F3CD.png
#   inflating: resizeopenmoji128/1F3CE.png
#   inflating: resizeopenmoji128/1F3CF.png
#   inflating: resizeopenmoji128/1F3D0.png
#   inflating: resizeopenmoji128/1F3D1.png
#   inflating: resizeopenmoji128/1F3D2.png
#   inflating: resizeopenmoji128/1F3D3.png
#   inflating: resizeopenmoji128/1F3D4.png
#   inflating: resizeopenmoji128/1F3D5.png
#   inflating: resizeopenmoji128/1F3D6.png
#   inflating: resizeopenmoji128/1F3D7.png
#   inflating: resizeopenmoji128/1F3D8.png
#   inflating: resizeopenmoji128/1F3D9.png
#   inflating: resizeopenmoji128/1F3DA.png
#   inflating: resizeopenmoji128/1F3DB.png
#   inflating: resizeopenmoji128/1F3DC.png
#   inflating: resizeopenmoji128/1F3DD.png
#   inflating: resizeopenmoji128/1F3DE.png
#   inflating: resizeopenmoji128/1F3DF.png
#   inflating: resizeopenmoji128/1F3E0.png
#   inflating: resizeopenmoji128/1F3E1.png
#   inflating: resizeopenmoji128/1F3E2.png
#   inflating: resizeopenmoji128/1F3E3.png
#   inflating: resizeopenmoji128/1F3E4.png
#   inflating: resizeopenmoji128/1F3E5.png
#   inflating: resizeopenmoji128/1F3E6.png
#   inflating: resizeopenmoji128/1F3E7.png
#   inflating: resizeopenmoji128/1F3E8.png
#   inflating: resizeopenmoji128/1F3E9.png
#   inflating: resizeopenmoji128/1F3EA.png
#   inflating: resizeopenmoji128/1F3EB.png
#   inflating: resizeopenmoji128/1F3EC.png
#   inflating: resizeopenmoji128/1F3ED.png
#   inflating: resizeopenmoji128/1F3EE.png
#   inflating: resizeopenmoji128/1F3EF.png
#   inflating: resizeopenmoji128/1F3F0.png
#   inflating: resizeopenmoji128/1F3F3-FE0F-200D-1F308.png
#   inflating: resizeopenmoji128/1F3F3-FE0F-200D-26A7-FE0F.png
#   inflating: resizeopenmoji128/1F3F3.png
#   inflating: resizeopenmoji128/1F3F4-200D-2620-FE0F.png
#   inflating: resizeopenmoji128/1F3F4-E0067-E0062-E0065-E006E-E0067-E007F.png
#   inflating: resizeopenmoji128/1F3F4-E0067-E0062-E0073-E0063-E0074-E007F.png
#   inflating: resizeopenmoji128/1F3F4-E0067-E0062-E0077-E006C-E0073-E007F.png
#   inflating: resizeopenmoji128/1F3F4.png
#   inflating: resizeopenmoji128/1F3F5.png
#   inflating: resizeopenmoji128/1F3F7.png
#   inflating: resizeopenmoji128/1F3F8.png
#   inflating: resizeopenmoji128/1F3F9.png
#   inflating: resizeopenmoji128/1F3FA.png
#   inflating: resizeopenmoji128/1F3FB.png
#   inflating: resizeopenmoji128/1F3FC.png
#   inflating: resizeopenmoji128/1F3FD.png
#   inflating: resizeopenmoji128/1F3FE.png
#   inflating: resizeopenmoji128/1F3FF.png
#   inflating: resizeopenmoji128/1F400.png
#   inflating: resizeopenmoji128/1F401.png
#   inflating: resizeopenmoji128/1F402.png
#   inflating: resizeopenmoji128/1F403.png
#   inflating: resizeopenmoji128/1F404.png
#   inflating: resizeopenmoji128/1F405.png
#   inflating: resizeopenmoji128/1F406.png
#   inflating: resizeopenmoji128/1F407.png
#   inflating: resizeopenmoji128/1F408-200D-2B1B.png
#   inflating: resizeopenmoji128/1F408.png
#   inflating: resizeopenmoji128/1F409.png
#   inflating: resizeopenmoji128/1F40A.png
#   inflating: resizeopenmoji128/1F40B.png
#   inflating: resizeopenmoji128/1F40C.png
#   inflating: resizeopenmoji128/1F40D.png
#   inflating: resizeopenmoji128/1F40E.png
#   inflating: resizeopenmoji128/1F40F.png
#   inflating: resizeopenmoji128/1F410.png
#   inflating: resizeopenmoji128/1F411.png
#   inflating: resizeopenmoji128/1F412.png
#   inflating: resizeopenmoji128/1F413.png
#   inflating: resizeopenmoji128/1F414.png
#   inflating: resizeopenmoji128/1F415-200D-1F9BA.png
#   inflating: resizeopenmoji128/1F415.png
#   inflating: resizeopenmoji128/1F416.png
#   inflating: resizeopenmoji128/1F417.png
#   inflating: resizeopenmoji128/1F418.png
#   inflating: resizeopenmoji128/1F419.png
#   inflating: resizeopenmoji128/1F41A.png
#   inflating: resizeopenmoji128/1F41B.png
#   inflating: resizeopenmoji128/1F41C.png
#   inflating: resizeopenmoji128/1F41D.png
#   inflating: resizeopenmoji128/1F41E.png
#   inflating: resizeopenmoji128/1F41F.png
#   inflating: resizeopenmoji128/1F420.png
#   inflating: resizeopenmoji128/1F421.png
#   inflating: resizeopenmoji128/1F422.png
#   inflating: resizeopenmoji128/1F423.png
#   inflating: resizeopenmoji128/1F424.png
#   inflating: resizeopenmoji128/1F425.png
#   inflating: resizeopenmoji128/1F426-200D-1F525.png
#   inflating: resizeopenmoji128/1F426-200D-2B1B.png
#   inflating: resizeopenmoji128/1F426.png
#   inflating: resizeopenmoji128/1F427.png
#   inflating: resizeopenmoji128/1F428.png
#   inflating: resizeopenmoji128/1F429.png
#   inflating: resizeopenmoji128/1F42A.png
#   inflating: resizeopenmoji128/1F42B.png
#   inflating: resizeopenmoji128/1F42C.png
#   inflating: resizeopenmoji128/1F42D.png
#   inflating: resizeopenmoji128/1F42E.png
#   inflating: resizeopenmoji128/1F42F.png
#   inflating: resizeopenmoji128/1F430.png
#   inflating: resizeopenmoji128/1F431.png
#   inflating: resizeopenmoji128/1F432.png
#   inflating: resizeopenmoji128/1F433.png
#   inflating: resizeopenmoji128/1F434.png
#   inflating: resizeopenmoji128/1F435.png
#   inflating: resizeopenmoji128/1F436.png
#   inflating: resizeopenmoji128/1F437.png
#   inflating: resizeopenmoji128/1F438.png
#   inflating: resizeopenmoji128/1F439.png
#   inflating: resizeopenmoji128/1F43A.png
#   inflating: resizeopenmoji128/1F43B-200D-2744-FE0F.png
#   inflating: resizeopenmoji128/1F43B.png
#   inflating: resizeopenmoji128/1F43C.png
#   inflating: resizeopenmoji128/1F43D.png
#   inflating: resizeopenmoji128/1F43E.png
#   inflating: resizeopenmoji128/1F43F.png
#   inflating: resizeopenmoji128/1F440.png
#   inflating: resizeopenmoji128/1F441-FE0F-200D-1F5E8-FE0F.png
#   inflating: resizeopenmoji128/1F441.png
#   inflating: resizeopenmoji128/1F442.png
#   inflating: resizeopenmoji128/1F443.png
#   inflating: resizeopenmoji128/1F444.png
#   inflating: resizeopenmoji128/1F445.png
#   inflating: resizeopenmoji128/1F446.png
#   inflating: resizeopenmoji128/1F447.png
#   inflating: resizeopenmoji128/1F448.png
#   inflating: resizeopenmoji128/1F449.png
#   inflating: resizeopenmoji128/1F44A.png
#   inflating: resizeopenmoji128/1F44B.png
#   inflating: resizeopenmoji128/1F44C.png
#   inflating: resizeopenmoji128/1F44D.png
#   inflating: resizeopenmoji128/1F44E.png
#   inflating: resizeopenmoji128/1F44F.png
#   inflating: resizeopenmoji128/1F450.png
#   inflating: resizeopenmoji128/1F451.png
#   inflating: resizeopenmoji128/1F452.png
#   inflating: resizeopenmoji128/1F453.png
#   inflating: resizeopenmoji128/1F454.png
#   inflating: resizeopenmoji128/1F455.png
#   inflating: resizeopenmoji128/1F456.png
#   inflating: resizeopenmoji128/1F457.png
#   inflating: resizeopenmoji128/1F458.png
#   inflating: resizeopenmoji128/1F459.png
#   inflating: resizeopenmoji128/1F45A.png
#   inflating: resizeopenmoji128/1F45B.png
#   inflating: resizeopenmoji128/1F45C.png
#   inflating: resizeopenmoji128/1F45D.png
#   inflating: resizeopenmoji128/1F45E.png
#   inflating: resizeopenmoji128/1F45F.png
#   inflating: resizeopenmoji128/1F460.png
#   inflating: resizeopenmoji128/1F461.png
#   inflating: resizeopenmoji128/1F462.png
#   inflating: resizeopenmoji128/1F463.png
#   inflating: resizeopenmoji128/1F464.png
#   inflating: resizeopenmoji128/1F465.png
#   inflating: resizeopenmoji128/1F466.png
#   inflating: resizeopenmoji128/1F467.png
#   inflating: resizeopenmoji128/1F468-200D-1F33E.png
#   inflating: resizeopenmoji128/1F468-200D-1F373.png
#   inflating: resizeopenmoji128/1F468-200D-1F37C.png
#   inflating: resizeopenmoji128/1F468-200D-1F393.png
#   inflating: resizeopenmoji128/1F468-200D-1F3A4.png
#   inflating: resizeopenmoji128/1F468-200D-1F3A8.png
#   inflating: resizeopenmoji128/1F468-200D-1F3EB.png
#   inflating: resizeopenmoji128/1F468-200D-1F3ED.png
#   inflating: resizeopenmoji128/1F468-200D-1F466-200D-1F466.png
#   inflating: resizeopenmoji128/1F468-200D-1F466.png
#   inflating: resizeopenmoji128/1F468-200D-1F467-200D-1F466.png
#   inflating: resizeopenmoji128/1F468-200D-1F467-200D-1F467.png
#   inflating: resizeopenmoji128/1F468-200D-1F467.png
#   inflating: resizeopenmoji128/1F468-200D-1F468-200D-1F466-200D-1F466.png
#   inflating: resizeopenmoji128/1F468-200D-1F468-200D-1F466.png
#   inflating: resizeopenmoji128/1F468-200D-1F468-200D-1F467-200D-1F466.png
#   inflating: resizeopenmoji128/1F468-200D-1F468-200D-1F467-200D-1F467.png
#   inflating: resizeopenmoji128/1F468-200D-1F468-200D-1F467.png
#   inflating: resizeopenmoji128/1F468-200D-1F469-200D-1F466-200D-1F466.png
#   inflating: resizeopenmoji128/1F468-200D-1F469-200D-1F466.png
#   inflating: resizeopenmoji128/1F468-200D-1F469-200D-1F467-200D-1F466.png
#   inflating: resizeopenmoji128/1F468-200D-1F469-200D-1F467-200D-1F467.png
#   inflating: resizeopenmoji128/1F468-200D-1F469-200D-1F467.png
#   inflating: resizeopenmoji128/1F468-200D-1F4BB.png
#   inflating: resizeopenmoji128/1F468-200D-1F4BC.png
#   inflating: resizeopenmoji128/1F468-200D-1F527.png
#   inflating: resizeopenmoji128/1F468-200D-1F52C.png
#   inflating: resizeopenmoji128/1F468-200D-1F680.png
#   inflating: resizeopenmoji128/1F468-200D-1F692.png
#   inflating: resizeopenmoji128/1F468-200D-1F9AF-200D-27A1-FE0F.png
#   inflating: resizeopenmoji128/1F468-200D-1F9AF.png
#   inflating: resizeopenmoji128/1F468-200D-1F9B0.png
#   inflating: resizeopenmoji128/1F468-200D-1F9B1.png
#   inflating: resizeopenmoji128/1F468-200D-1F9B2.png
#   inflating: resizeopenmoji128/1F468-200D-1F9B3.png
#   inflating: resizeopenmoji128/1F468-200D-1F9BC-200D-27A1-FE0F.png
#   inflating: resizeopenmoji128/1F468-200D-1F9BC.png
#   inflating: resizeopenmoji128/1F468-200D-1F9BD-200D-27A1-FE0F.png
#   inflating: resizeopenmoji128/1F468-200D-1F9BD.png
#   inflating: resizeopenmoji128/1F468-200D-2695-FE0F.png
#   inflating: resizeopenmoji128/1F468-200D-2696-FE0F.png
#   inflating: resizeopenmoji128/1F468-200D-2708-FE0F.png
#   inflating: resizeopenmoji128/1F468-200D-2764-FE0F-200D-1F468.png
#   inflating: resizeopenmoji128/1F468-200D-2764-FE0F-200D-1F48B-200D-1F468.png
#   inflating: resizeopenmoji128/1F468.png
#   inflating: resizeopenmoji128/1F469-200D-1F33E.png
#   inflating: resizeopenmoji128/1F469-200D-1F373.png
#   inflating: resizeopenmoji128/1F469-200D-1F37C.png
#   inflating: resizeopenmoji128/1F469-200D-1F393.png
#   inflating: resizeopenmoji128/1F469-200D-1F3A4.png
#   inflating: resizeopenmoji128/1F469-200D-1F3A8.png
#   inflating: resizeopenmoji128/1F469-200D-1F3EB.png
#   inflating: resizeopenmoji128/1F469-200D-1F3ED.png
#   inflating: resizeopenmoji128/1F469-200D-1F466-200D-1F466.png
#   inflating: resizeopenmoji128/1F469-200D-1F466.png
#   inflating: resizeopenmoji128/1F469-200D-1F467-200D-1F466.png
#   inflating: resizeopenmoji128/1F469-200D-1F467-200D-1F467.png
#   inflating: resizeopenmoji128/1F469-200D-1F467.png
#   inflating: resizeopenmoji128/1F469-200D-1F469-200D-1F466-200D-1F466.png
#   inflating: resizeopenmoji128/1F469-200D-1F469-200D-1F466.png
#   inflating: resizeopenmoji128/1F469-200D-1F469-200D-1F467-200D-1F466.png
#   inflating: resizeopenmoji128/1F469-200D-1F469-200D-1F467-200D-1F467.png
#   inflating: resizeopenmoji128/1F469-200D-1F469-200D-1F467.png
#   inflating: resizeopenmoji128/1F469-200D-1F4BB.png
#   inflating: resizeopenmoji128/1F469-200D-1F4BC.png
#   inflating: resizeopenmoji128/1F469-200D-1F527.png
#   inflating: resizeopenmoji128/1F469-200D-1F52C.png
#   inflating: resizeopenmoji128/1F469-200D-1F680.png
#   inflating: resizeopenmoji128/1F469-200D-1F692.png
#   inflating: resizeopenmoji128/1F469-200D-1F9AF-200D-27A1-FE0F.png
#   inflating: resizeopenmoji128/1F469-200D-1F9AF.png
#   inflating: resizeopenmoji128/1F469-200D-1F9B0.png
#   inflating: resizeopenmoji128/1F469-200D-1F9B1.png
#   inflating: resizeopenmoji128/1F469-200D-1F9B2.png
#   inflating: resizeopenmoji128/1F469-200D-1F9B3.png
#   inflating: resizeopenmoji128/1F469-200D-1F9BC-200D-27A1-FE0F.png
#   inflating: resizeopenmoji128/1F469-200D-1F9BC.png
#   inflating: resizeopenmoji128/1F469-200D-1F9BD-200D-27A1-FE0F.png
#   inflating: resizeopenmoji128/1F469-200D-1F9BD.png
#   inflating: resizeopenmoji128/1F469-200D-2695-FE0F.png
#   inflating: resizeopenmoji128/1F469-200D-2696-FE0F.png
#   inflating: resizeopenmoji128/1F469-200D-2708-FE0F.png
#   inflating: resizeopenmoji128/1F469-200D-2764-FE0F-200D-1F468.png
#   inflating: resizeopenmoji128/1F469-200D-2764-FE0F-200D-1F469.png
#   inflating: resizeopenmoji128/1F469-200D-2764-FE0F-200D-1F48B-200D-1F468.png
#   inflating: resizeopenmoji128/1F469-200D-2764-FE0F-200D-1F48B-200D-1F469.png
#   inflating: resizeopenmoji128/1F469.png
#   inflating: resizeopenmoji128/1F46A.png
#   inflating: resizeopenmoji128/1F46B.png
#   inflating: resizeopenmoji128/1F46C.png
#   inflating: resizeopenmoji128/1F46D.png
#   inflating: resizeopenmoji128/1F46E-200D-2640-FE0F.png
#   inflating: resizeopenmoji128/1F46E-200D-2642-FE0F.png
#   inflating: resizeopenmoji128/1F46E.png
#   inflating: resizeopenmoji128/1F46F-200D-2640-FE0F.png
#   inflating: resizeopenmoji128/1F46F-200D-2642-FE0F.png
#   inflating: resizeopenmoji128/1F46F.png
#   inflating: resizeopenmoji128/1F470-200D-2640-FE0F.png
#   inflating: resizeopenmoji128/1F470-200D-2642-FE0F.png
#   inflating: resizeopenmoji128/1F470.png
#   inflating: resizeopenmoji128/1F471-200D-2640-FE0F.png
#   inflating: resizeopenmoji128/1F471-200D-2642-FE0F.png
#   inflating: resizeopenmoji128/1F471.png
#   inflating: resizeopenmoji128/1F472.png
#   inflating: resizeopenmoji128/1F473-200D-2640-FE0F.png
#   inflating: resizeopenmoji128/1F473-200D-2642-FE0F.png
#   inflating: resizeopenmoji128/1F473.png
#   inflating: resizeopenmoji128/1F474.png
#   inflating: resizeopenmoji128/1F475.png
#   inflating: resizeopenmoji128/1F476.png
#   inflating: resizeopenmoji128/1F477-200D-2640-FE0F.png
#   inflating: resizeopenmoji128/1F477-200D-2642-FE0F.png
#   inflating: resizeopenmoji128/1F477.png
#   inflating: resizeopenmoji128/1F478.png
#   inflating: resizeopenmoji128/1F479.png
#   inflating: resizeopenmoji128/1F47A.png
#   inflating: resizeopenmoji128/1F47B.png
#   inflating: resizeopenmoji128/1F47C.png
#   inflating: resizeopenmoji128/1F47D.png
#   inflating: resizeopenmoji128/1F47E.png
#   inflating: resizeopenmoji128/1F47F.png
#   inflating: resizeopenmoji128/1F480.png
#   inflating: resizeopenmoji128/1F481-200D-2640-FE0F.png
#   inflating: resizeopenmoji128/1F481-200D-2642-FE0F.png
#   inflating: resizeopenmoji128/1F481.png
#   inflating: resizeopenmoji128/1F482-200D-2640-FE0F.png
#   inflating: resizeopenmoji128/1F482-200D-2642-FE0F.png
#   inflating: resizeopenmoji128/1F482.png
#   inflating: resizeopenmoji128/1F483.png
#   inflating: resizeopenmoji128/1F484.png
#   inflating: resizeopenmoji128/1F485.png
#   inflating: resizeopenmoji128/1F486-200D-2640-FE0F.png
#   inflating: resizeopenmoji128/1F486-200D-2642-FE0F.png
#   inflating: resizeopenmoji128/1F486.png
#   inflating: resizeopenmoji128/1F487-200D-2640-FE0F.png
#   inflating: resizeopenmoji128/1F487-200D-2642-FE0F.png
#   inflating: resizeopenmoji128/1F487.png
#   inflating: resizeopenmoji128/1F488.png
#   inflating: resizeopenmoji128/1F489.png
#   inflating: resizeopenmoji128/1F48A.png
#   inflating: resizeopenmoji128/1F48B.png
#   inflating: resizeopenmoji128/1F48C.png
#   inflating: resizeopenmoji128/1F48D.png
#   inflating: resizeopenmoji128/1F48E.png
#   inflating: resizeopenmoji128/1F48F.png
#   inflating: resizeopenmoji128/1F490.png
#   inflating: resizeopenmoji128/1F491.png
#   inflating: resizeopenmoji128/1F492.png
#   inflating: resizeopenmoji128/1F493.png
#   inflating: resizeopenmoji128/1F494.png
#   inflating: resizeopenmoji128/1F495.png
#   inflating: resizeopenmoji128/1F496.png
#   inflating: resizeopenmoji128/1F497.png
#   inflating: resizeopenmoji128/1F498.png
#   inflating: resizeopenmoji128/1F499.png
#   inflating: resizeopenmoji128/1F49A.png
#   inflating: resizeopenmoji128/1F49B.png
#   inflating: resizeopenmoji128/1F49C.png
#   inflating: resizeopenmoji128/1F49D.png
#   inflating: resizeopenmoji128/1F49E.png
#   inflating: resizeopenmoji128/1F49F.png
#   inflating: resizeopenmoji128/1F4A0.png
#   inflating: resizeopenmoji128/1F4A1.png
#   inflating: resizeopenmoji128/1F4A2.png
#   inflating: resizeopenmoji128/1F4A3.png
#   inflating: resizeopenmoji128/1F4A4.png
#   inflating: resizeopenmoji128/1F4A5.png
#   inflating: resizeopenmoji128/1F4A6.png
#  extracting: resizeopenmoji128/1F4A7.png
#   inflating: resizeopenmoji128/1F4A8.png
#   inflating: resizeopenmoji128/1F4A9.png
#   inflating: resizeopenmoji128/1F4AA.png
#   inflating: resizeopenmoji128/1F4AB.png
#   inflating: resizeopenmoji128/1F4AC.png
#   inflating: resizeopenmoji128/1F4AD.png
#   inflating: resizeopenmoji128/1F4AE.png
#   inflating: resizeopenmoji128/1F4AF.png
#   inflating: resizeopenmoji128/1F4B0.png
#   inflating: resizeopenmoji128/1F4B1.png
#   inflating: resizeopenmoji128/1F4B2.png
#   inflating: resizeopenmoji128/1F4B3.png
#   inflating: resizeopenmoji128/1F4B4.png
#   inflating: resizeopenmoji128/1F4B5.png
#   inflating: resizeopenmoji128/1F4B6.png
#   inflating: resizeopenmoji128/1F4B7.png
#   inflating: resizeopenmoji128/1F4B8.png
#   inflating: resizeopenmoji128/1F4B9.png
#   inflating: resizeopenmoji128/1F4BA.png
#   inflating: resizeopenmoji128/1F4BB.png
#   inflating: resizeopenmoji128/1F4BC.png
#   inflating: resizeopenmoji128/1F4BD.png
#   inflating: resizeopenmoji128/1F4BE.png
#   inflating: resizeopenmoji128/1F4BF.png
#   inflating: resizeopenmoji128/1F4C0.png
#   inflating: resizeopenmoji128/1F4C1.png
#   inflating: resizeopenmoji128/1F4C2.png
#   inflating: resizeopenmoji128/1F4C3.png
#   inflating: resizeopenmoji128/1F4C4.png
#   inflating: resizeopenmoji128/1F4C5.png
#   inflating: resizeopenmoji128/1F4C6.png
#   inflating: resizeopenmoji128/1F4C7.png
#   inflating: resizeopenmoji128/1F4C8.png
#   inflating: resizeopenmoji128/1F4C9.png
#   inflating: resizeopenmoji128/1F4CA.png
#   inflating: resizeopenmoji128/1F4CB.png
#   inflating: resizeopenmoji128/1F4CC.png
#   inflating: resizeopenmoji128/1F4CD.png
#   inflating: resizeopenmoji128/1F4CE.png
#   inflating: resizeopenmoji128/1F4CF.png
#   inflating: resizeopenmoji128/1F4D0.png
#   inflating: resizeopenmoji128/1F4D1.png
#   inflating: resizeopenmoji128/1F4D2.png
#   inflating: resizeopenmoji128/1F4D3.png
#   inflating: resizeopenmoji128/1F4D4.png
#   inflating: resizeopenmoji128/1F4D5.png
#   inflating: resizeopenmoji128/1F4D6.png
#   inflating: resizeopenmoji128/1F4D7.png
#   inflating: resizeopenmoji128/1F4D8.png
#   inflating: resizeopenmoji128/1F4D9.png
#   inflating: resizeopenmoji128/1F4DA.png
#   inflating: resizeopenmoji128/1F4DB.png
#   inflating: resizeopenmoji128/1F4DC.png
#   inflating: resizeopenmoji128/1F4DD.png
#   inflating: resizeopenmoji128/1F4DE.png
#   inflating: resizeopenmoji128/1F4DF.png
#   inflating: resizeopenmoji128/1F4E0.png
#   inflating: resizeopenmoji128/1F4E1.png
#   inflating: resizeopenmoji128/1F4E2.png
#   inflating: resizeopenmoji128/1F4E3.png
#   inflating: resizeopenmoji128/1F4E4.png
#   inflating: resizeopenmoji128/1F4E5.png
#   inflating: resizeopenmoji128/1F4E6.png
#   inflating: resizeopenmoji128/1F4E7.png
#   inflating: resizeopenmoji128/1F4E8.png
#   inflating: resizeopenmoji128/1F4E9.png
#   inflating: resizeopenmoji128/1F4EA.png
#   inflating: resizeopenmoji128/1F4EB.png
#   inflating: resizeopenmoji128/1F4EC.png
#   inflating: resizeopenmoji128/1F4ED.png
#   inflating: resizeopenmoji128/1F4EE.png
#   inflating: resizeopenmoji128/1F4EF.png
#   inflating: resizeopenmoji128/1F4F0.png
#   inflating: resizeopenmoji128/1F4F1.png
#   inflating: resizeopenmoji128/1F4F2.png
#   inflating: resizeopenmoji128/1F4F3.png
#   inflating: resizeopenmoji128/1F4F4.png
#   inflating: resizeopenmoji128/1F4F5.png
#   inflating: resizeopenmoji128/1F4F6.png
#   inflating: resizeopenmoji128/1F4F7.png
#   inflating: resizeopenmoji128/1F4F8.png
#   inflating: resizeopenmoji128/1F4F9.png
#   inflating: resizeopenmoji128/1F4FA.png
#   inflating: resizeopenmoji128/1F4FB.png
#   inflating: resizeopenmoji128/1F4FC.png
#   inflating: resizeopenmoji128/1F4FD.png
#   inflating: resizeopenmoji128/1F4FF.png
#   inflating: resizeopenmoji128/1F500.png
#   inflating: resizeopenmoji128/1F501.png
#   inflating: resizeopenmoji128/1F502.png
#   inflating: resizeopenmoji128/1F503.png
#   inflating: resizeopenmoji128/1F504.png
#   inflating: resizeopenmoji128/1F505.png
#   inflating: resizeopenmoji128/1F506.png
#   inflating: resizeopenmoji128/1F507.png
#   inflating: resizeopenmoji128/1F508.png
#   inflating: resizeopenmoji128/1F509.png
#   inflating: resizeopenmoji128/1F50A.png
#   inflating: resizeopenmoji128/1F50B.png
#   inflating: resizeopenmoji128/1F50C.png
#   inflating: resizeopenmoji128/1F50D.png
#   inflating: resizeopenmoji128/1F50E.png
#   inflating: resizeopenmoji128/1F50F.png
#   inflating: resizeopenmoji128/1F510.png
#   inflating: resizeopenmoji128/1F511.png
#   inflating: resizeopenmoji128/1F512.png
#   inflating: resizeopenmoji128/1F513.png
#   inflating: resizeopenmoji128/1F514.png
#   inflating: resizeopenmoji128/1F515.png
#   inflating: resizeopenmoji128/1F516.png
#   inflating: resizeopenmoji128/1F517.png
#   inflating: resizeopenmoji128/1F518.png
#   inflating: resizeopenmoji128/1F519.png
#   inflating: resizeopenmoji128/1F51A.png
#   inflating: resizeopenmoji128/1F51B.png
#   inflating: resizeopenmoji128/1F51C.png
#   inflating: resizeopenmoji128/1F51D.png
#   inflating: resizeopenmoji128/1F51E.png
#   inflating: resizeopenmoji128/1F51F.png
#   inflating: resizeopenmoji128/1F520.png
#   inflating: resizeopenmoji128/1F521.png
#   inflating: resizeopenmoji128/1F522.png
#   inflating: resizeopenmoji128/1F523.png
#   inflating: resizeopenmoji128/1F524.png
#   inflating: resizeopenmoji128/1F525.png
#   inflating: resizeopenmoji128/1F526.png
#   inflating: resizeopenmoji128/1F527.png
#   inflating: resizeopenmoji128/1F528.png
#   inflating: resizeopenmoji128/1F529.png
#   inflating: resizeopenmoji128/1F52A.png
#   inflating: resizeopenmoji128/1F52B.png
#   inflating: resizeopenmoji128/1F52C.png
#   inflating: resizeopenmoji128/1F52D.png
#   inflating: resizeopenmoji128/1F52E.png
#   inflating: resizeopenmoji128/1F52F.png
#   inflating: resizeopenmoji128/1F530.png
#   inflating: resizeopenmoji128/1F531.png
#   inflating: resizeopenmoji128/1F532.png
#   inflating: resizeopenmoji128/1F533.png
#   inflating: resizeopenmoji128/1F534.png
#   inflating: resizeopenmoji128/1F535.png
#   inflating: resizeopenmoji128/1F536.png
#   inflating: resizeopenmoji128/1F537.png
#   inflating: resizeopenmoji128/1F538.png
#   inflating: resizeopenmoji128/1F539.png
#   inflating: resizeopenmoji128/1F53A.png
# ...
#   inflating: resizeopenmoji128/1F9D1-200D-1F9B3.png
#   inflating: resizeopenmoji128/1F9D1-200D-1F9BC-200D-27A1-FE0F.png
#   inflating: resizeopenmoji128/1F9D1-200D-1F9BC.png
#   inflating: resizeopenmoji128/1F9D1-200D-1F9BD-200D-27A1-FE0F.png
#   inflating: resizeopenmoji128/1F9D1-200D-1F9BD.png
#   inflating: resizeopenmoji128/1F9D1-200D-1F9D1-200D-1F9D2-200D-1F9D2.png
#   inflating: resizeopenmoji128/1F9D1-200D-1F9D1-200D-1F9D2.png
#   inflating: resizeopenmoji128/1F9D1-200D-1F9D2-200D-1F9D2.png
#   inflating: resizeopenmoji128/1F9D1-200D-1F9D2.png
#   inflating: resizeopenmoji128/1F9D1-200D-2695-FE0F.png
#   inflating: resizeopenmoji128/1F9D1-200D-2696-FE0F.png
#   inflating: resizeopenmoji128/1F9D1-200D-2708-FE0F.png
#   inflating: resizeopenmoji128/1F9D1.png
#   inflating: resizeopenmoji128/1F9D2.png
#   inflating: resizeopenmoji128/1F9D3.png
#   inflating: resizeopenmoji128/1F9D4-200D-2640-FE0F.png
#   inflating: resizeopenmoji128/1F9D4-200D-2642-FE0F.png
#   inflating: resizeopenmoji128/1F9D4.png
#   inflating: resizeopenmoji128/1F9D5.png
#   inflating: resizeopenmoji128/1F9D6-200D-2640-FE0F.png
#   inflating: resizeopenmoji128/1F9D6-200D-2642-FE0F.png
#   inflating: resizeopenmoji128/1F9D6.png
#   inflating: resizeopenmoji128/1F9D7-200D-2640-FE0F.png
#   inflating: resizeopenmoji128/1F9D7-200D-2642-FE0F.png
#   inflating: resizeopenmoji128/1F9D7.png
#   inflating: resizeopenmoji128/1F9D8-200D-2640-FE0F.png
#   inflating: resizeopenmoji128/1F9D8-200D-2642-FE0F.png
#   inflating: resizeopenmoji128/1F9D8.png
#   inflating: resizeopenmoji128/1F9D9-200D-2640-FE0F.png
#   inflating: resizeopenmoji128/1F9D9-200D-2642-FE0F.png
#   inflating: resizeopenmoji128/1F9D9.png
#   inflating: resizeopenmoji128/1F9DA-200D-2640-FE0F.png
#   inflating: resizeopenmoji128/1F9DA-200D-2642-FE0F.png
#   inflating: resizeopenmoji128/1F9DA.png
#   inflating: resizeopenmoji128/1F9DB-200D-2640-FE0F.png
#   inflating: resizeopenmoji128/1F9DB-200D-2642-FE0F.png
#   inflating: resizeopenmoji128/1F9DB.png
#   inflating: resizeopenmoji128/1F9DC-200D-2640-FE0F.png
#   inflating: resizeopenmoji128/1F9DC-200D-2642-FE0F.png
#   inflating: resizeopenmoji128/1F9DC.png
#   inflating: resizeopenmoji128/1F9DD-200D-2640-FE0F.png
#   inflating: resizeopenmoji128/1F9DD-200D-2642-FE0F.png
#   inflating: resizeopenmoji128/1F9DD.png
#   inflating: resizeopenmoji128/1F9DE-200D-2640-FE0F.png
#   inflating: resizeopenmoji128/1F9DE-200D-2642-FE0F.png
#   inflating: resizeopenmoji128/1F9DE.png
#   inflating: resizeopenmoji128/1F9DF-200D-2640-FE0F.png
#   inflating: resizeopenmoji128/1F9DF-200D-2642-FE0F.png
#   inflating: resizeopenmoji128/1F9DF.png
#   inflating: resizeopenmoji128/1F9E0.png
#   inflating: resizeopenmoji128/1F9E1.png
#   inflating: resizeopenmoji128/1F9E2.png
#   inflating: resizeopenmoji128/1F9E3.png
#   inflating: resizeopenmoji128/1F9E4.png
#   inflating: resizeopenmoji128/1F9E5.png
#   inflating: resizeopenmoji128/1F9E6.png
#   inflating: resizeopenmoji128/1F9E7.png
#   inflating: resizeopenmoji128/1F9E8.png
#   inflating: resizeopenmoji128/1F9E9.png
#   inflating: resizeopenmoji128/1F9EA.png
#   inflating: resizeopenmoji128/1F9EB.png
#   inflating: resizeopenmoji128/1F9EC.png
#   inflating: resizeopenmoji128/1F9ED.png
#   inflating: resizeopenmoji128/1F9EE.png
#   inflating: resizeopenmoji128/1F9EF.png
#   inflating: resizeopenmoji128/1F9F0.png
#   inflating: resizeopenmoji128/1F9F1.png
#   inflating: resizeopenmoji128/1F9F2.png
#   inflating: resizeopenmoji128/1F9F3.png
#   inflating: resizeopenmoji128/1F9F4.png
#   inflating: resizeopenmoji128/1F9F5.png
#   inflating: resizeopenmoji128/1F9F6.png
#   inflating: resizeopenmoji128/1F9F7.png
#   inflating: resizeopenmoji128/1F9F8.png
#   inflating: resizeopenmoji128/1F9F9.png
#   inflating: resizeopenmoji128/1F9FA.png
#   inflating: resizeopenmoji128/1F9FB.png
#   inflating: resizeopenmoji128/1F9FC.png
#   inflating: resizeopenmoji128/1F9FD.png
#   inflating: resizeopenmoji128/1F9FE.png
#   inflating: resizeopenmoji128/1F9FF.png
#   inflating: resizeopenmoji128/1FA70.png
#   inflating: resizeopenmoji128/1FA71.png
#   inflating: resizeopenmoji128/1FA72.png
#   inflating: resizeopenmoji128/1FA73.png
#   inflating: resizeopenmoji128/1FA74.png
#   inflating: resizeopenmoji128/1FA75.png
#   inflating: resizeopenmoji128/1FA76.png
#   inflating: resizeopenmoji128/1FA77.png
#  extracting: resizeopenmoji128/1FA78.png
#   inflating: resizeopenmoji128/1FA79.png
#   inflating: resizeopenmoji128/1FA7A.png
#   inflating: resizeopenmoji128/1FA7B.png
#   inflating: resizeopenmoji128/1FA7C.png
#   inflating: resizeopenmoji128/1FA80.png
#   inflating: resizeopenmoji128/1FA81.png
#   inflating: resizeopenmoji128/1FA82.png
#   inflating: resizeopenmoji128/1FA83.png
#   inflating: resizeopenmoji128/1FA84.png
#   inflating: resizeopenmoji128/1FA85.png
#   inflating: resizeopenmoji128/1FA86.png
#   inflating: resizeopenmoji128/1FA87.png
#   inflating: resizeopenmoji128/1FA88.png
#   inflating: resizeopenmoji128/1FA90.png
#   inflating: resizeopenmoji128/1FA91.png
#   inflating: resizeopenmoji128/1FA92.png
#   inflating: resizeopenmoji128/1FA93.png
#   inflating: resizeopenmoji128/1FA94.png
#   inflating: resizeopenmoji128/1FA95.png
#   inflating: resizeopenmoji128/1FA96.png
#   inflating: resizeopenmoji128/1FA97.png
#   inflating: resizeopenmoji128/1FA98.png
#   inflating: resizeopenmoji128/1FA99.png
#   inflating: resizeopenmoji128/1FA9A.png
#   inflating: resizeopenmoji128/1FA9B.png
#   inflating: resizeopenmoji128/1FA9C.png
#   inflating: resizeopenmoji128/1FA9D.png
#   inflating: resizeopenmoji128/1FA9E.png
#   inflating: resizeopenmoji128/1FA9F.png
#   inflating: resizeopenmoji128/1FAA0.png
#   inflating: resizeopenmoji128/1FAA1.png
#   inflating: resizeopenmoji128/1FAA2.png
#   inflating: resizeopenmoji128/1FAA3.png
#   inflating: resizeopenmoji128/1FAA4.png
#   inflating: resizeopenmoji128/1FAA5.png
#   inflating: resizeopenmoji128/1FAA6.png
#   inflating: resizeopenmoji128/1FAA7.png
#   inflating: resizeopenmoji128/1FAA8.png
#   inflating: resizeopenmoji128/1FAA9.png
#   inflating: resizeopenmoji128/1FAAA.png
#   inflating: resizeopenmoji128/1FAAB.png
#   inflating: resizeopenmoji128/1FAAC.png
#   inflating: resizeopenmoji128/1FAAD.png
#   inflating: resizeopenmoji128/1FAAE.png
#   inflating: resizeopenmoji128/1FAAF.png
#   inflating: resizeopenmoji128/1FAB0.png
#   inflating: resizeopenmoji128/1FAB1.png
#   inflating: resizeopenmoji128/1FAB2.png
#   inflating: resizeopenmoji128/1FAB3.png
#   inflating: resizeopenmoji128/1FAB4.png
#   inflating: resizeopenmoji128/1FAB5.png
#   inflating: resizeopenmoji128/1FAB6.png
#   inflating: resizeopenmoji128/1FAB7.png
#   inflating: resizeopenmoji128/1FAB8.png
#   inflating: resizeopenmoji128/1FAB9.png
#   inflating: resizeopenmoji128/1FABA.png
#   inflating: resizeopenmoji128/1FABB.png
#   inflating: resizeopenmoji128/1FABC.png
#   inflating: resizeopenmoji128/1FABD.png
#   inflating: resizeopenmoji128/1FABF.png
#   inflating: resizeopenmoji128/1FAC0.png
#   inflating: resizeopenmoji128/1FAC1.png
#   inflating: resizeopenmoji128/1FAC2.png
#   inflating: resizeopenmoji128/1FAC3.png
#   inflating: resizeopenmoji128/1FAC4.png
#   inflating: resizeopenmoji128/1FAC5.png
#   inflating: resizeopenmoji128/1FACE.png
#   inflating: resizeopenmoji128/1FACF.png
#   inflating: resizeopenmoji128/1FAD0.png
#   inflating: resizeopenmoji128/1FAD1.png
#   inflating: resizeopenmoji128/1FAD2.png
#   inflating: resizeopenmoji128/1FAD3.png
#   inflating: resizeopenmoji128/1FAD4.png
#   inflating: resizeopenmoji128/1FAD5.png
#   inflating: resizeopenmoji128/1FAD6.png
#   inflating: resizeopenmoji128/1FAD7.png
#   inflating: resizeopenmoji128/1FAD8.png
#   inflating: resizeopenmoji128/1FAD9.png
#   inflating: resizeopenmoji128/1FADA.png
#   inflating: resizeopenmoji128/1FADB.png
#   inflating: resizeopenmoji128/1FAE0.png
#   inflating: resizeopenmoji128/1FAE1.png
#   inflating: resizeopenmoji128/1FAE2.png
#   inflating: resizeopenmoji128/1FAE3.png
#   inflating: resizeopenmoji128/1FAE4.png
#   inflating: resizeopenmoji128/1FAE5.png
#   inflating: resizeopenmoji128/1FAE6.png
#   inflating: resizeopenmoji128/1FAE7.png
#   inflating: resizeopenmoji128/1FAE8.png
#   inflating: resizeopenmoji128/1FAF0.png
#   inflating: resizeopenmoji128/1FAF1.png
#   inflating: resizeopenmoji128/1FAF2.png
#   inflating: resizeopenmoji128/1FAF3.png
#   inflating: resizeopenmoji128/1FAF4.png
#   inflating: resizeopenmoji128/1FAF5.png
#   inflating: resizeopenmoji128/1FAF6.png
#   inflating: resizeopenmoji128/1FAF7.png
#   inflating: resizeopenmoji128/1FAF8.png
#   inflating: resizeopenmoji128/203C.png
#   inflating: resizeopenmoji128/2049.png
#   inflating: resizeopenmoji128/2122.png
#   inflating: resizeopenmoji128/2139.png
#   inflating: resizeopenmoji128/2194.png
#   inflating: resizeopenmoji128/2195.png
#   inflating: resizeopenmoji128/2196.png
#   inflating: resizeopenmoji128/2197.png
#   inflating: resizeopenmoji128/2198.png
#   inflating: resizeopenmoji128/2199.png
#   inflating: resizeopenmoji128/21A9.png
#   inflating: resizeopenmoji128/21AA.png
#   inflating: resizeopenmoji128/231A.png
#   inflating: resizeopenmoji128/231B.png
#   inflating: resizeopenmoji128/2328.png
#   inflating: resizeopenmoji128/23CF.png
#   inflating: resizeopenmoji128/23E9.png
#   inflating: resizeopenmoji128/23EA.png
#   inflating: resizeopenmoji128/23EB.png
#   inflating: resizeopenmoji128/23EC.png
#   inflating: resizeopenmoji128/23ED.png
#   inflating: resizeopenmoji128/23EE.png
#   inflating: resizeopenmoji128/23EF.png
#   inflating: resizeopenmoji128/23F0.png
#   inflating: resizeopenmoji128/23F1.png
#   inflating: resizeopenmoji128/23F2.png
#   inflating: resizeopenmoji128/23F3.png
#   inflating: resizeopenmoji128/23F8.png
#   inflating: resizeopenmoji128/23F9.png
#   inflating: resizeopenmoji128/23FA.png
#   inflating: resizeopenmoji128/24C2.png
#   inflating: resizeopenmoji128/25AA.png
#   inflating: resizeopenmoji128/25AB.png
#   inflating: resizeopenmoji128/25B6.png
#   inflating: resizeopenmoji128/25C0.png
#   inflating: resizeopenmoji128/25FB.png
#   inflating: resizeopenmoji128/25FC.png
#   inflating: resizeopenmoji128/25FD.png
#   inflating: resizeopenmoji128/25FE.png
#   inflating: resizeopenmoji128/2600.png
#   inflating: resizeopenmoji128/2601.png
#   inflating: resizeopenmoji128/2602.png
#   inflating: resizeopenmoji128/2603.png
#   inflating: resizeopenmoji128/2604.png
#   inflating: resizeopenmoji128/260E.png
#   inflating: resizeopenmoji128/2611.png
#   inflating: resizeopenmoji128/2614.png
#   inflating: resizeopenmoji128/2615.png
#   inflating: resizeopenmoji128/2618.png
#   inflating: resizeopenmoji128/261D.png
#   inflating: resizeopenmoji128/2620.png
#   inflating: resizeopenmoji128/2622.png
#   inflating: resizeopenmoji128/2623.png
#   inflating: resizeopenmoji128/2626.png
#   inflating: resizeopenmoji128/262A.png
#   inflating: resizeopenmoji128/262E.png
#   inflating: resizeopenmoji128/262F.png
#   inflating: resizeopenmoji128/2638.png
#   inflating: resizeopenmoji128/2639.png
#   inflating: resizeopenmoji128/263A.png
#   inflating: resizeopenmoji128/2640.png
#   inflating: resizeopenmoji128/2642.png
#   inflating: resizeopenmoji128/2648.png
#   inflating: resizeopenmoji128/2649.png
#   inflating: resizeopenmoji128/264A.png
#   inflating: resizeopenmoji128/264B.png
#   inflating: resizeopenmoji128/264C.png
#   inflating: resizeopenmoji128/264D.png
#   inflating: resizeopenmoji128/264E.png
#   inflating: resizeopenmoji128/264F.png
#   inflating: resizeopenmoji128/2650.png
#   inflating: resizeopenmoji128/2651.png
#   inflating: resizeopenmoji128/2652.png
#   inflating: resizeopenmoji128/2653.png
#   inflating: resizeopenmoji128/265F.png
#   inflating: resizeopenmoji128/2660.png
#   inflating: resizeopenmoji128/2663.png
#   inflating: resizeopenmoji128/2665.png
#   inflating: resizeopenmoji128/2666.png
#   inflating: resizeopenmoji128/2668.png
#   inflating: resizeopenmoji128/267B.png
#   inflating: resizeopenmoji128/267E.png
#   inflating: resizeopenmoji128/267F.png
#   inflating: resizeopenmoji128/2692.png
#   inflating: resizeopenmoji128/2693.png
#   inflating: resizeopenmoji128/2694.png
#   inflating: resizeopenmoji128/2695.png
#   inflating: resizeopenmoji128/2696.png
#   inflating: resizeopenmoji128/2697.png
#   inflating: resizeopenmoji128/2699.png
#   inflating: resizeopenmoji128/269B.png
#   inflating: resizeopenmoji128/269C.png
#   inflating: resizeopenmoji128/26A0.png
#   inflating: resizeopenmoji128/26A1.png
#   inflating: resizeopenmoji128/26A7.png
#   inflating: resizeopenmoji128/26AA.png
#   inflating: resizeopenmoji128/26AB.png
#   inflating: resizeopenmoji128/26B0.png
#   inflating: resizeopenmoji128/26B1.png
#   inflating: resizeopenmoji128/26BD.png
#   inflating: resizeopenmoji128/26BE.png
#   inflating: resizeopenmoji128/26C4.png
#   inflating: resizeopenmoji128/26C5.png
#   inflating: resizeopenmoji128/26C8.png
#   inflating: resizeopenmoji128/26CE.png
#   inflating: resizeopenmoji128/26CF.png
#   inflating: resizeopenmoji128/26D1.png
#   inflating: resizeopenmoji128/26D3-FE0F-200D-1F4A5.png
#   inflating: resizeopenmoji128/26D3.png
#   inflating: resizeopenmoji128/26D4.png
#   inflating: resizeopenmoji128/26E9.png
#   inflating: resizeopenmoji128/26EA.png
#   inflating: resizeopenmoji128/26F0.png
#   inflating: resizeopenmoji128/26F1.png
#   inflating: resizeopenmoji128/26F2.png
#   inflating: resizeopenmoji128/26F3.png
#   inflating: resizeopenmoji128/26F4.png
#   inflating: resizeopenmoji128/26F5.png
#   inflating: resizeopenmoji128/26F7.png
#   inflating: resizeopenmoji128/26F8.png
#   inflating: resizeopenmoji128/26F9-FE0F-200D-2640-FE0F.png
#   inflating: resizeopenmoji128/26F9-FE0F-200D-2642-FE0F.png
#   inflating: resizeopenmoji128/26F9.png
#   inflating: resizeopenmoji128/26FA.png
#   inflating: resizeopenmoji128/26FD.png
#   inflating: resizeopenmoji128/2702.png
#   inflating: resizeopenmoji128/2705.png
#   inflating: resizeopenmoji128/2708.png
#   inflating: resizeopenmoji128/2709.png
#   inflating: resizeopenmoji128/270A.png
#   inflating: resizeopenmoji128/270B.png
#   inflating: resizeopenmoji128/270C.png
#   inflating: resizeopenmoji128/270D.png
#   inflating: resizeopenmoji128/270F.png
#   inflating: resizeopenmoji128/2712.png
#   inflating: resizeopenmoji128/2714.png
#   inflating: resizeopenmoji128/2716.png
#   inflating: resizeopenmoji128/271D.png
#   inflating: resizeopenmoji128/2721.png
#   inflating: resizeopenmoji128/2728.png
#   inflating: resizeopenmoji128/2733.png
#   inflating: resizeopenmoji128/2734.png
#   inflating: resizeopenmoji128/2744.png
#   inflating: resizeopenmoji128/2747.png
#   inflating: resizeopenmoji128/274C.png
#   inflating: resizeopenmoji128/274E.png
#   inflating: resizeopenmoji128/2753.png
#   inflating: resizeopenmoji128/2754.png
#   inflating: resizeopenmoji128/2755.png
#   inflating: resizeopenmoji128/2757.png
#   inflating: resizeopenmoji128/2763.png
#   inflating: resizeopenmoji128/2764-FE0F-200D-1F525.png
#   inflating: resizeopenmoji128/2764-FE0F-200D-1FA79.png
#   inflating: resizeopenmoji128/2764.png
#   inflating: resizeopenmoji128/2795.png
#   inflating: resizeopenmoji128/2796.png
#   inflating: resizeopenmoji128/2797.png
#   inflating: resizeopenmoji128/27A1.png
#   inflating: resizeopenmoji128/27B0.png
#   inflating: resizeopenmoji128/27BF.png
#   inflating: resizeopenmoji128/2934.png
#   inflating: resizeopenmoji128/2935.png
#   inflating: resizeopenmoji128/2B05.png
#   inflating: resizeopenmoji128/2B06.png
#   inflating: resizeopenmoji128/2B07.png
#   inflating: resizeopenmoji128/2B1B.png
#   inflating: resizeopenmoji128/2B1C.png
#   inflating: resizeopenmoji128/2B50.png
#   inflating: resizeopenmoji128/2B55.png
#   inflating: resizeopenmoji128/3030.png
#   inflating: resizeopenmoji128/303D.png
#   inflating: resizeopenmoji128/3297.png
#   inflating: resizeopenmoji128/3299.png

# %%
import pandas as pd
import os

# Path to your CSV
file_path = '/content/metadata128.csv'  # change to your actual CSV path

# Load CSV
df = pd.read_csv(file_path)

# New base directory
new_base = "/content/resizeopenmoji128"

# Update the image_path column to use the new base + original filename
df['image_path'] = df['image_path'].apply(lambda p: os.path.join(new_base, os.path.basename(str(p))))

# Save updated CSV
updated_path = '/content/metadata128_updated.csv'
df.to_csv(updated_path, index=False)

print(f"Updated CSV saved to: {updated_path}")
# Out:
# Updated CSV saved to: /content/metadata128_updated.csv

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
from PIL import Image, ImageDraw, ImageFont
import pandas as pd
import os
import numpy as np

# --- 1. DCGAN MODEL ARCHITECTURES FOR 128x128 ---
class Generator(nn.Module):
    def __init__(self, z_dim, num_classes, embedding_dim, img_channels, features_g=64):
        super(Generator, self).__init__()
        self.z_dim, self.embedding_dim = z_dim, embedding_dim
        self.label_embedding = nn.Embedding(num_classes, embedding_dim)
        self.net = nn.Sequential(
            self._block(z_dim + embedding_dim, features_g * 16, 4, 1, 0), # 4x4
            self._block(features_g * 16, features_g * 8, 4, 2, 1),      # 8x8
            self._block(features_g * 8, features_g * 4, 4, 2, 1),       # 16x16
            self._block(features_g * 4, features_g * 2, 4, 2, 1),       # 32x32
            self._block(features_g * 2, features_g, 4, 2, 1),           # 64x64
            nn.ConvTranspose2d(features_g, img_channels, 4, 2, 1),      # 128x128
            nn.Tanh(),
        )
    def _block(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(nn.ConvTranspose2d(in_channels, out_channels, kernel_size, stride, padding, bias=False), nn.BatchNorm2d(out_channels), nn.ReLU(True))
    def forward(self, noise, labels):
        label_embeddings = self.label_embedding(labels)
        x = torch.cat((noise, label_embeddings), -1).view(-1, self.z_dim + self.embedding_dim, 1, 1)
        return self.net(x)

class Discriminator(nn.Module):
    def __init__(self, num_classes, embedding_dim, img_channels, features_d=64):
        super(Discriminator, self).__init__()
        self.embedding_dim = embedding_dim
        self.label_embedding = nn.Embedding(num_classes, embedding_dim)
        self.image_net = nn.Sequential(
            nn.Conv2d(img_channels + embedding_dim, features_d, 4, 2, 1), # Combine image and label at the start
            nn.LeakyReLU(0.2, inplace=True),
            self._block(features_d, features_d * 2, 4, 2, 1),
            self._block(features_d * 2, features_d * 4, 4, 2, 1),
            self._block(features_d * 4, features_d * 8, 4, 2, 1),
            self._block(features_d * 8, features_d * 16, 4, 2, 1),
            nn.Conv2d(features_d * 16, 1, 4, 1, 0),
            nn.Sigmoid() # Use Sigmoid with BCELoss
        )
    def _block(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding, bias=False), nn.BatchNorm2d(out_channels), nn.LeakyReLU(0.2, inplace=True))
    def forward(self, img, labels):
        label_embeddings = self.label_embedding(labels).view(labels.shape[0], self.embedding_dim, 1, 1)
        label_features = label_embeddings.expand(-1, -1, img.shape[2], img.shape[3])
        x = torch.cat([img, label_features], dim=1)
        output = self.image_net(x)
        return output.view(x.size(0), -1)

# --- 2. DATASET AND UTILITY FUNCTIONS ---
class EmojiDataset(Dataset):
    def __init__(self, dataframe, transform=None):
        self.metadata = dataframe.reset_index(drop=True)
        self.transform = transform
        self.shortcodes = self.metadata['shortcode'].unique()
        self.shortcode_to_idx = {c: i for i, c in enumerate(self.shortcodes)}
        self.num_classes = len(self.shortcodes)
    def __len__(self): return len(self.metadata)
    def __getitem__(self, idx):
        # Use the 'image_path' column which now points to the resized images
        img_path = self.metadata.loc[idx, 'image_path']
        shortcode = self.metadata.loc[idx, 'shortcode']
        try:
            image = Image.open(img_path).convert('RGB')
        except FileNotFoundError:
            return None, None
        label = self.shortcode_to_idx[shortcode]
        if self.transform:
            image = self.transform(image)
        return image, torch.tensor(label, dtype=torch.long)

def collate_fn(batch):
    batch = list(filter(lambda x: x is not None and x[0] is not None, batch))
    if not batch: return torch.Tensor(), torch.Tensor()
    return torch.utils.data.dataloader.default_collate(batch)

def save_labeled_image_grid(images_tensor, labels, epoch, idx_to_shortcode, file_path="generated_images_128"):
    os.makedirs(file_path, exist_ok=True)
    num_images, img_size = images_tensor.shape[0], images_tensor.shape[2]
    nrow = int(np.sqrt(num_images))
    padding, text_h = 10, 20
    grid_size = nrow * (img_size + padding) + padding
    total_height = grid_size + nrow * text_h
    grid_img = Image.new('RGB', (grid_size, total_height), 'white')
    draw = ImageDraw.Draw(grid_img)
    try: font = ImageFont.truetype("Arial.ttf", 15)
    except IOError: font = ImageFont.load_default()
    for i in range(num_images):
        img_tensor = (images_tensor[i].detach().cpu() * 0.5) + 0.5
        img_pil = transforms.ToPILImage()(img_tensor)
        row, col = i // nrow, i % nrow
        x = col * (img_size + padding) + padding
        y = row * (img_size + padding + text_h) + padding
        grid_img.paste(img_pil, (x, y))
        shortcode = idx_to_shortcode[labels[i].item()]
        draw.text((x, y + img_size + 2), shortcode[:20], fill="black", font=font)
    grid_img.save(os.path.join(file_path, f"epoch_{epoch:03d}.png"))

# --- 3. MAIN EXECUTION BLOCK ---
if __name__ == '__main__':
    # Configuration
    DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
    LR, BATCH_SIZE, IMAGE_SIZE = 4e-4, 16, 128 # Smaller batch size for larger images
    CHANNELS_IMG, Z_DIM, EMBEDDING_DIM, NUM_EPOCHS = 3, 100, 50, 200

    # Use the new 128x128 metadata file
    CSV_FILE = '/content/metadata128_updated.csv'

    # Step 1: Load and filter metadata
    print("Step 1: Loading and cleaning metadata...")
    try:
        metadata_df = pd.read_csv(CSV_FILE)
        metadata_df.dropna(subset=['unicode', 'shortcode', 'group'], inplace=True)
        groups_to_keep = [0.0]
        mask = metadata_df['group'].isin(groups_to_keep)
        metadata_df = metadata_df[mask].copy()
        print(f"  - Filtered dataset has {len(metadata_df)} samples.")
    except FileNotFoundError: print(f"FATAL: Metadata file not found at {CSV_FILE}"); exit()

    # Step 2: Setup Dataloader
    print("\nStep 2: Setting up data loader...")
    transform = transforms.Compose([
        transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
        transforms.ToTensor(),
        transforms.Normalize([0.5]*3, [0.5]*3),
    ])
    dataset = EmojiDataset(dataframe=metadata_df, transform=transform)
    dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True, collate_fn=collate_fn, num_workers=4, pin_memory=True)
    if len(dataset) == 0: print("FATAL: The dataset is empty."); exit()
    NUM_CLASSES = dataset.num_classes
    idx_to_shortcode = {v: k for k, v in dataset.shortcode_to_idx.items()}
    print(idx_to_shortcode)

    # Step 3: Initialize Models
    print("\nStep 3: Initializing models...")
    generator = Generator(Z_DIM, NUM_CLASSES, EMBEDDING_DIM, CHANNELS_IMG).to(DEVICE)
    discriminator = Discriminator(NUM_CLASSES, EMBEDDING_DIM, CHANNELS_IMG).to(DEVICE)
    optimizer_G = optim.Adam(generator.parameters(), lr=LR, betas=(0.5, 0.999))
    optimizer_D = optim.Adam(discriminator.parameters(), lr=LR, betas=(0.5, 0.999))
    criterion = nn.BCELoss() # Using BCELoss as requested

    # Visualization setup
    fixed_noise = torch.randn(64, Z_DIM, device=DEVICE)
    fixed_labels = torch.randint(0, NUM_CLASSES, (64,), device=DEVICE)

    # Step 4: Training Loop
    print(f"\nStep 4: Starting training on {DEVICE}...")
    for epoch in range(NUM_EPOCHS):
        for batch_idx, (real_imgs, labels) in enumerate(dataloader):
            if real_imgs.nelement() == 0: continue
            real_imgs, labels = real_imgs.to(DEVICE), labels.to(DEVICE)
            # Label Smoothing
            valid = torch.full((real_imgs.shape[0], 1), 0.9, device=DEVICE)
            fake = torch.full((real_imgs.shape[0], 1), 0.1, device=DEVICE)

            # Train Discriminator
            optimizer_D.zero_grad()
            noise = torch.randn(real_imgs.shape[0], Z_DIM, device=DEVICE)
            fake_imgs = generator(noise, labels)
            d_real_loss = criterion(discriminator(real_imgs, labels), valid)
            d_fake_loss = criterion(discriminator(fake_imgs.detach(), labels), fake)
            d_loss = (d_real_loss + d_fake_loss) / 2
            d_loss.backward(); optimizer_D.step()

            # Train Generator
            optimizer_G.zero_grad()
            g_loss = criterion(discriminator(fake_imgs, labels), valid)
            g_loss.backward(); optimizer_G.step()

            if batch_idx % 50 == 0:
                print(f"[Epoch {epoch+1:03d}/{NUM_EPOCHS}] [Batch {batch_idx:04d}/{len(dataloader)}] [D loss: {d_loss.item():.4f}] [G loss: {g_loss.item():.4f}]")

        # Save visualization grid
        generator.eval()
        with torch.no_grad():
            sample_imgs = generator(fixed_noise, fixed_labels)
            save_labeled_image_grid(sample_imgs, fixed_labels, epoch + 1, idx_to_shortcode)
        generator.train()

    # Save final models
    torch.save(generator.state_dict(), 'generator_128.pth')
    torch.save(discriminator.state_dict(), 'discriminator_128.pth')
    print("\nTraining finished. 🎉")
# Out:
# Step 1: Loading and cleaning metadata...
#   - Filtered dataset has 166 samples.
#
# Step 2: Setting up data loader...
#
# Step 3: Initializing models...
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Step 4: Starting training on cuda...
# [Epoch 001/200] [Batch 0000/11] [D loss: 0.6992] [G loss: 7.6160]
# [Epoch 002/200] [Batch 0000/11] [D loss: 0.7896] [G loss: 0.7149]
# [Epoch 003/200] [Batch 0000/11] [D loss: 0.7905] [G loss: 0.9946]
# [Epoch 004/200] [Batch 0000/11] [D loss: 0.7380] [G loss: 1.0112]
# [Epoch 005/200] [Batch 0000/11] [D loss: 0.7509] [G loss: 0.7890]
# [Epoch 006/200] [Batch 0000/11] [D loss: 0.7403] [G loss: 0.6857]
# [Epoch 007/200] [Batch 0000/11] [D loss: 0.7149] [G loss: 0.6695]
# [Epoch 008/200] [Batch 0000/11] [D loss: 0.7182] [G loss: 0.6544]
# [Epoch 009/200] [Batch 0000/11] [D loss: 0.7070] [G loss: 0.7273]
# [Epoch 010/200] [Batch 0000/11] [D loss: 0.6941] [G loss: 0.6750]
# [Epoch 011/200] [Batch 0000/11] [D loss: 0.7131] [G loss: 0.7542]
# [Epoch 012/200] [Batch 0000/11] [D loss: 0.8459] [G loss: 0.8688]
# [Epoch 013/200] [Batch 0000/11] [D loss: 0.8113] [G loss: 0.8476]
# [Epoch 014/200] [Batch 0000/11] [D loss: 0.7055] [G loss: 0.7314]
# [Epoch 015/200] [Batch 0000/11] [D loss: 0.6883] [G loss: 1.0729]
# [Epoch 016/200] [Batch 0000/11] [D loss: 0.8295] [G loss: 0.5027]
# [Epoch 017/200] [Batch 0000/11] [D loss: 0.7345] [G loss: 0.8085]
# [Epoch 018/200] [Batch 0000/11] [D loss: 0.9394] [G loss: 0.5813]
# [Epoch 019/200] [Batch 0000/11] [D loss: 1.0003] [G loss: 0.8084]
# [Epoch 020/200] [Batch 0000/11] [D loss: 0.6853] [G loss: 0.6835]
# [Epoch 021/200] [Batch 0000/11] [D loss: 0.7120] [G loss: 0.8380]
# [Epoch 022/200] [Batch 0000/11] [D loss: 0.6757] [G loss: 1.0929]
# [Epoch 023/200] [Batch 0000/11] [D loss: 0.7319] [G loss: 1.0897]
# [Epoch 024/200] [Batch 0000/11] [D loss: 0.7108] [G loss: 0.6624]
# [Epoch 025/200] [Batch 0000/11] [D loss: 0.7225] [G loss: 0.9653]
# [Epoch 026/200] [Batch 0000/11] [D loss: 0.8316] [G loss: 0.7073]
# [Epoch 027/200] [Batch 0000/11] [D loss: 1.0423] [G loss: 0.8949]
# [Epoch 028/200] [Batch 0000/11] [D loss: 0.8924] [G loss: 0.9257]
# [Epoch 029/200] [Batch 0000/11] [D loss: 0.6366] [G loss: 0.8355]
# [Epoch 030/200] [Batch 0000/11] [D loss: 0.8377] [G loss: 0.6594]
# [Epoch 031/200] [Batch 0000/11] [D loss: 0.6870] [G loss: 0.7504]
# [Epoch 032/200] [Batch 0000/11] [D loss: 0.7248] [G loss: 0.7419]
# [Epoch 033/200] [Batch 0000/11] [D loss: 0.7492] [G loss: 0.6814]
# [Epoch 034/200] [Batch 0000/11] [D loss: 0.7204] [G loss: 0.7628]
# [Epoch 035/200] [Batch 0000/11] [D loss: 0.6911] [G loss: 0.8614]
# [Epoch 036/200] [Batch 0000/11] [D loss: 0.6905] [G loss: 0.6803]
# [Epoch 037/200] [Batch 0000/11] [D loss: 0.7337] [G loss: 0.6810]
# [Epoch 038/200] [Batch 0000/11] [D loss: 0.7198] [G loss: 0.6548]
# [Epoch 039/200] [Batch 0000/11] [D loss: 0.7940] [G loss: 0.7051]
# [Epoch 040/200] [Batch 0000/11] [D loss: 0.7022] [G loss: 0.6599]
# [Epoch 041/200] [Batch 0000/11] [D loss: 0.6898] [G loss: 0.7779]
# [Epoch 042/200] [Batch 0000/11] [D loss: 0.7646] [G loss: 0.6216]
# [Epoch 043/200] [Batch 0000/11] [D loss: 0.7459] [G loss: 0.7837]
# [Epoch 044/200] [Batch 0000/11] [D loss: 0.7893] [G loss: 1.0122]
# [Epoch 045/200] [Batch 0000/11] [D loss: 0.6657] [G loss: 0.8377]
# [Epoch 046/200] [Batch 0000/11] [D loss: 1.0474] [G loss: 1.9608]
# [Epoch 047/200] [Batch 0000/11] [D loss: 0.7242] [G loss: 0.8539]
# [Epoch 048/200] [Batch 0000/11] [D loss: 0.7297] [G loss: 0.9680]
# [Epoch 049/200] [Batch 0000/11] [D loss: 0.6706] [G loss: 0.7756]
# [Epoch 050/200] [Batch 0000/11] [D loss: 0.7192] [G loss: 0.7438]
# [Epoch 051/200] [Batch 0000/11] [D loss: 0.7371] [G loss: 0.9451]
# [Epoch 052/200] [Batch 0000/11] [D loss: 0.6770] [G loss: 0.8477]
# [Epoch 053/200] [Batch 0000/11] [D loss: 0.7516] [G loss: 0.8707]
# [Epoch 054/200] [Batch 0000/11] [D loss: 0.7180] [G loss: 0.7852]
# [Epoch 055/200] [Batch 0000/11] [D loss: 0.7549] [G loss: 1.4716]
# [Epoch 056/200] [Batch 0000/11] [D loss: 0.6914] [G loss: 0.7335]
# [Epoch 057/200] [Batch 0000/11] [D loss: 0.7291] [G loss: 1.2686]
# [Epoch 058/200] [Batch 0000/11] [D loss: 0.8181] [G loss: 0.6798]
# [Epoch 059/200] [Batch 0000/11] [D loss: 0.7706] [G loss: 0.6724]
# [Epoch 060/200] [Batch 0000/11] [D loss: 1.1675] [G loss: 0.6975]
# [Epoch 061/200] [Batch 0000/11] [D loss: 0.7508] [G loss: 1.0549]
# [Epoch 062/200] [Batch 0000/11] [D loss: 0.6598] [G loss: 0.8223]
# [Epoch 063/200] [Batch 0000/11] [D loss: 0.7628] [G loss: 0.8276]
# [Epoch 064/200] [Batch 0000/11] [D loss: 0.7285] [G loss: 0.7498]
# [Epoch 065/200] [Batch 0000/11] [D loss: 0.7065] [G loss: 0.7411]
# [Epoch 066/200] [Batch 0000/11] [D loss: 0.8211] [G loss: 0.7296]
# [Epoch 067/200] [Batch 0000/11] [D loss: 0.7399] [G loss: 0.7817]
# [Epoch 068/200] [Batch 0000/11] [D loss: 0.7424] [G loss: 1.0045]
# [Epoch 069/200] [Batch 0000/11] [D loss: 0.6429] [G loss: 0.7903]
# [Epoch 070/200] [Batch 0000/11] [D loss: 0.7052] [G loss: 1.1547]
# [Epoch 071/200] [Batch 0000/11] [D loss: 0.6625] [G loss: 1.0674]
# [Epoch 072/200] [Batch 0000/11] [D loss: 0.8014] [G loss: 0.7195]
# [Epoch 073/200] [Batch 0000/11] [D loss: 0.7052] [G loss: 1.4131]
# [Epoch 074/200] [Batch 0000/11] [D loss: 0.8060] [G loss: 0.6010]
# [Epoch 075/200] [Batch 0000/11] [D loss: 0.7170] [G loss: 0.9804]
# [Epoch 076/200] [Batch 0000/11] [D loss: 0.7142] [G loss: 0.7864]
# [Epoch 077/200] [Batch 0000/11] [D loss: 1.0886] [G loss: 0.6730]
# [Epoch 078/200] [Batch 0000/11] [D loss: 0.6775] [G loss: 0.7658]
# [Epoch 079/200] [Batch 0000/11] [D loss: 0.6929] [G loss: 1.1698]
# [Epoch 080/200] [Batch 0000/11] [D loss: 0.6994] [G loss: 0.8525]
# [Epoch 081/200] [Batch 0000/11] [D loss: 0.6906] [G loss: 1.0404]
# [Epoch 082/200] [Batch 0000/11] [D loss: 0.6766] [G loss: 0.7708]
# [Epoch 083/200] [Batch 0000/11] [D loss: 0.8918] [G loss: 0.7903]
# [Epoch 084/200] [Batch 0000/11] [D loss: 0.6627] [G loss: 0.8693]
# [Epoch 085/200] [Batch 0000/11] [D loss: 0.7723] [G loss: 0.7855]
# [Epoch 086/200] [Batch 0000/11] [D loss: 0.7898] [G loss: 0.6595]
# [Epoch 087/200] [Batch 0000/11] [D loss: 0.7504] [G loss: 0.6679]
# [Epoch 088/200] [Batch 0000/11] [D loss: 0.6708] [G loss: 0.7793]
# [Epoch 089/200] [Batch 0000/11] [D loss: 0.6930] [G loss: 0.7516]
# [Epoch 090/200] [Batch 0000/11] [D loss: 0.8324] [G loss: 0.6712]
# [Epoch 091/200] [Batch 0000/11] [D loss: 0.7680] [G loss: 1.2275]
# [Epoch 092/200] [Batch 0000/11] [D loss: 0.7969] [G loss: 0.7496]
# [Epoch 093/200] [Batch 0000/11] [D loss: 0.7668] [G loss: 0.7514]
# [Epoch 094/200] [Batch 0000/11] [D loss: 0.7363] [G loss: 1.2383]
# [Epoch 095/200] [Batch 0000/11] [D loss: 0.6842] [G loss: 0.9731]
# [Epoch 096/200] [Batch 0000/11] [D loss: 0.6922] [G loss: 0.8360]
# [Epoch 097/200] [Batch 0000/11] [D loss: 0.7535] [G loss: 0.9554]
# [Epoch 098/200] [Batch 0000/11] [D loss: 0.7153] [G loss: 0.6961]
# [Epoch 099/200] [Batch 0000/11] [D loss: 0.6940] [G loss: 0.7196]
# [Epoch 100/200] [Batch 0000/11] [D loss: 0.7365] [G loss: 0.7323]
# [Epoch 101/200] [Batch 0000/11] [D loss: 0.6813] [G loss: 0.8095]
# [Epoch 102/200] [Batch 0000/11] [D loss: 0.7759] [G loss: 0.5889]
# [Epoch 103/200] [Batch 0000/11] [D loss: 0.6891] [G loss: 0.8118]
# [Epoch 104/200] [Batch 0000/11] [D loss: 0.7411] [G loss: 0.5682]
# [Epoch 105/200] [Batch 0000/11] [D loss: 0.6986] [G loss: 0.9163]
# [Epoch 106/200] [Batch 0000/11] [D loss: 0.6879] [G loss: 0.7475]
# [Epoch 107/200] [Batch 0000/11] [D loss: 0.7999] [G loss: 0.6133]
# [Epoch 108/200] [Batch 0000/11] [D loss: 0.8127] [G loss: 0.7516]
# [Epoch 109/200] [Batch 0000/11] [D loss: 0.7425] [G loss: 0.9965]
# [Epoch 110/200] [Batch 0000/11] [D loss: 0.8967] [G loss: 0.7352]
# [Epoch 111/200] [Batch 0000/11] [D loss: 0.7004] [G loss: 0.9101]
# [Epoch 112/200] [Batch 0000/11] [D loss: 0.6967] [G loss: 0.7285]
# [Epoch 113/200] [Batch 0000/11] [D loss: 0.7494] [G loss: 0.6618]
# [Epoch 114/200] [Batch 0000/11] [D loss: 0.7327] [G loss: 0.8539]
# [Epoch 115/200] [Batch 0000/11] [D loss: 0.7919] [G loss: 0.6661]
# [Epoch 116/200] [Batch 0000/11] [D loss: 0.7294] [G loss: 0.6752]
# [Epoch 117/200] [Batch 0000/11] [D loss: 0.7526] [G loss: 0.6246]
# [Epoch 118/200] [Batch 0000/11] [D loss: 0.7075] [G loss: 0.7730]
# [Epoch 119/200] [Batch 0000/11] [D loss: 0.7628] [G loss: 0.9123]
# [Epoch 120/200] [Batch 0000/11] [D loss: 0.6633] [G loss: 0.8081]
# [Epoch 121/200] [Batch 0000/11] [D loss: 0.7648] [G loss: 0.6580]
# [Epoch 122/200] [Batch 0000/11] [D loss: 0.6936] [G loss: 0.7163]
# [Epoch 123/200] [Batch 0000/11] [D loss: 1.0047] [G loss: 0.5985]
# [Epoch 124/200] [Batch 0000/11] [D loss: 0.7720] [G loss: 0.8197]
# [Epoch 125/200] [Batch 0000/11] [D loss: 0.8454] [G loss: 0.8558]
# [Epoch 126/200] [Batch 0000/11] [D loss: 0.6732] [G loss: 0.8359]
# [Epoch 127/200] [Batch 0000/11] [D loss: 0.6766] [G loss: 1.0987]
# [Epoch 128/200] [Batch 0000/11] [D loss: 0.6805] [G loss: 0.7873]
# [Epoch 129/200] [Batch 0000/11] [D loss: 0.7522] [G loss: 0.7452]
# [Epoch 130/200] [Batch 0000/11] [D loss: 0.7681] [G loss: 0.7541]
# [Epoch 131/200] [Batch 0000/11] [D loss: 0.7299] [G loss: 0.7368]
# [Epoch 132/200] [Batch 0000/11] [D loss: 0.6815] [G loss: 0.9050]
# [Epoch 133/200] [Batch 0000/11] [D loss: 0.7327] [G loss: 0.7143]
# [Epoch 134/200] [Batch 0000/11] [D loss: 0.9330] [G loss: 0.7404]
# [Epoch 135/200] [Batch 0000/11] [D loss: 0.7491] [G loss: 0.6772]
# [Epoch 136/200] [Batch 0000/11] [D loss: 0.6919] [G loss: 0.7258]
# [Epoch 137/200] [Batch 0000/11] [D loss: 0.6968] [G loss: 0.8045]
# [Epoch 138/200] [Batch 0000/11] [D loss: 0.6886] [G loss: 0.7507]
# [Epoch 139/200] [Batch 0000/11] [D loss: 0.6908] [G loss: 0.8211]
# [Epoch 140/200] [Batch 0000/11] [D loss: 0.6937] [G loss: 0.6994]
# [Epoch 141/200] [Batch 0000/11] [D loss: 0.7090] [G loss: 0.6941]
# [Epoch 142/200] [Batch 0000/11] [D loss: 0.6707] [G loss: 0.7458]
# [Epoch 143/200] [Batch 0000/11] [D loss: 0.6904] [G loss: 0.8253]
# [Epoch 144/200] [Batch 0000/11] [D loss: 0.7015] [G loss: 0.7598]
# [Epoch 145/200] [Batch 0000/11] [D loss: 0.7948] [G loss: 0.5137]
# [Epoch 146/200] [Batch 0000/11] [D loss: 0.8016] [G loss: 0.5482]
# [Epoch 147/200] [Batch 0000/11] [D loss: 0.7042] [G loss: 0.8201]
# [Epoch 148/200] [Batch 0000/11] [D loss: 0.6971] [G loss: 0.7570]
# [Epoch 149/200] [Batch 0000/11] [D loss: 0.7132] [G loss: 0.7188]
# [Epoch 150/200] [Batch 0000/11] [D loss: 0.7215] [G loss: 0.6978]
# [Epoch 151/200] [Batch 0000/11] [D loss: 0.7058] [G loss: 0.8048]
# [Epoch 152/200] [Batch 0000/11] [D loss: 0.8155] [G loss: 0.6706]
# [Epoch 153/200] [Batch 0000/11] [D loss: 0.6995] [G loss: 0.7655]
# [Epoch 154/200] [Batch 0000/11] [D loss: 0.7067] [G loss: 0.6789]
# [Epoch 155/200] [Batch 0000/11] [D loss: 0.7369] [G loss: 0.6267]
# [Epoch 156/200] [Batch 0000/11] [D loss: 0.6946] [G loss: 0.7055]
# [Epoch 157/200] [Batch 0000/11] [D loss: 0.6953] [G loss: 0.6428]
# [Epoch 158/200] [Batch 0000/11] [D loss: 0.7964] [G loss: 0.6298]
# [Epoch 159/200] [Batch 0000/11] [D loss: 0.6855] [G loss: 0.7675]
# [Epoch 160/200] [Batch 0000/11] [D loss: 0.6991] [G loss: 0.7335]
# [Epoch 161/200] [Batch 0000/11] [D loss: 0.7053] [G loss: 0.6939]
# [Epoch 162/200] [Batch 0000/11] [D loss: 0.6847] [G loss: 0.6931]
# [Epoch 163/200] [Batch 0000/11] [D loss: 0.7024] [G loss: 0.7325]
# [Epoch 164/200] [Batch 0000/11] [D loss: 0.7196] [G loss: 0.7396]
# [Epoch 165/200] [Batch 0000/11] [D loss: 0.7000] [G loss: 0.7145]
# [Epoch 166/200] [Batch 0000/11] [D loss: 0.7050] [G loss: 0.8138]
# [Epoch 167/200] [Batch 0000/11] [D loss: 0.6984] [G loss: 0.7787]
# [Epoch 168/200] [Batch 0000/11] [D loss: 0.6956] [G loss: 0.8101]
# [Epoch 169/200] [Batch 0000/11] [D loss: 0.7170] [G loss: 0.6769]
# [Epoch 170/200] [Batch 0000/11] [D loss: 0.6942] [G loss: 0.7578]
# [Epoch 171/200] [Batch 0000/11] [D loss: 0.7019] [G loss: 0.7254]
# [Epoch 172/200] [Batch 0000/11] [D loss: 0.7067] [G loss: 0.6791]
# [Epoch 173/200] [Batch 0000/11] [D loss: 0.6991] [G loss: 0.7078]
# [Epoch 174/200] [Batch 0000/11] [D loss: 0.6913] [G loss: 0.7479]
# [Epoch 175/200] [Batch 0000/11] [D loss: 0.6904] [G loss: 0.7508]
# [Epoch 176/200] [Batch 0000/11] [D loss: 0.6971] [G loss: 0.6882]
# [Epoch 177/200] [Batch 0000/11] [D loss: 0.7107] [G loss: 0.6851]
# [Epoch 178/200] [Batch 0000/11] [D loss: 0.6941] [G loss: 0.6932]
# [Epoch 179/200] [Batch 0000/11] [D loss: 0.6943] [G loss: 0.7193]
# [Epoch 180/200] [Batch 0000/11] [D loss: 0.6990] [G loss: 0.8056]
# [Epoch 181/200] [Batch 0000/11] [D loss: 0.6922] [G loss: 0.6937]
# [Epoch 182/200] [Batch 0000/11] [D loss: 0.6947] [G loss: 0.7310]
# [Epoch 183/200] [Batch 0000/11] [D loss: 0.6947] [G loss: 0.6908]
# [Epoch 184/200] [Batch 0000/11] [D loss: 0.7073] [G loss: 0.7417]
# [Epoch 185/200] [Batch 0000/11] [D loss: 0.6956] [G loss: 0.7819]
# [Epoch 186/200] [Batch 0000/11] [D loss: 0.7010] [G loss: 0.6923]
# [Epoch 187/200] [Batch 0000/11] [D loss: 0.7051] [G loss: 0.6084]
# [Epoch 188/200] [Batch 0000/11] [D loss: 0.7085] [G loss: 0.8603]
# [Epoch 189/200] [Batch 0000/11] [D loss: 0.7412] [G loss: 0.5917]
# [Epoch 190/200] [Batch 0000/11] [D loss: 0.7040] [G loss: 0.6142]
# [Epoch 191/200] [Batch 0000/11] [D loss: 0.7352] [G loss: 0.7291]
# [Epoch 192/200] [Batch 0000/11] [D loss: 0.6933] [G loss: 0.7021]
# [Epoch 193/200] [Batch 0000/11] [D loss: 0.7993] [G loss: 0.5210]
# [Epoch 194/200] [Batch 0000/11] [D loss: 0.7341] [G loss: 0.6688]
# [Epoch 195/200] [Batch 0000/11] [D loss: 0.6999] [G loss: 0.6933]
# [Epoch 196/200] [Batch 0000/11] [D loss: 0.7021] [G loss: 0.7270]
# [Epoch 197/200] [Batch 0000/11] [D loss: 0.7106] [G loss: 0.6943]
# [Epoch 198/200] [Batch 0000/11] [D loss: 0.6957] [G loss: 0.7311]
# [Epoch 199/200] [Batch 0000/11] [D loss: 0.7175] [G loss: 0.7737]
# [Epoch 200/200] [Batch 0000/11] [D loss: 0.7056] [G loss: 0.6728]
#
# Training finished. 🎉

# %%
if __name__ == '__main__':
    # Configuration
    DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
    LR, BATCH_SIZE, IMAGE_SIZE = 4e-4, 16, 128 # Smaller batch size for larger images
    CHANNELS_IMG, Z_DIM, EMBEDDING_DIM, NUM_EPOCHS = 3, 100, 50, 200

    # Use the new 128x128 metadata file
    CSV_FILE = '/content/metadata128_updated.csv'

    # Step 1: Load and filter metadata
    print("Step 1: Loading and cleaning metadata...")
    try:
        metadata_df = pd.read_csv(CSV_FILE)
        metadata_df.dropna(subset=['unicode', 'shortcode', 'group'], inplace=True)
        groups_to_keep = [0.0]
        mask = metadata_df['group'].isin(groups_to_keep)
        metadata_df = metadata_df[mask].copy()
        print(f"  - Filtered dataset has {len(metadata_df)} samples.")
    except FileNotFoundError: print(f"FATAL: Metadata file not found at {CSV_FILE}"); exit()

    # Step 2: Setup Dataloader
    print("\nStep 2: Setting up data loader...")
    transform = transforms.Compose([
        transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
        transforms.ToTensor(),
        transforms.Normalize([0.5]*3, [0.5]*3),
    ])
    dataset = EmojiDataset(dataframe=metadata_df, transform=transform)
    dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True, collate_fn=collate_fn, num_workers=4, pin_memory=True)
    if len(dataset) == 0: print("FATAL: The dataset is empty."); exit()
    NUM_CLASSES = dataset.num_classes
    idx_to_shortcode = {v: k for k, v in dataset.shortcode_to_idx.items()}
    print(idx_to_shortcode)
# Out:
# Step 1: Loading and cleaning metadata...
#   - Filtered dataset has 166 samples.
#
# Step 2: Setting up data loader...
# {0: 'grinning', 1: 'smiley', 2: 'smile', 3: 'grin', 4: "['laughing', 'satisfied']", 5: 'sweat_smile', 6: 'rofl', 7: 'joy', 8: 'slightly_smiling_face', 9: 'upside_down_face', 10: 'melting_face', 11: 'wink', 12: 'blush', 13: 'innocent', 14: 'smiling_face_with_three_hearts', 15: 'heart_eyes', 16: 'star_struck', 17: 'kissing_heart', 18: 'kissing', 19: 'relaxed', 20: 'kissing_closed_eyes', 21: 'kissing_smiling_eyes', 22: 'smiling_face_with_tear', 23: 'yum', 24: 'stuck_out_tongue', 25: 'stuck_out_tongue_winking_eye', 26: 'zany_face', 27: 'stuck_out_tongue_closed_eyes', 28: 'money_mouth_face', 29: 'hugs', 30: 'hand_over_mouth', 31: 'face_with_open_eyes_and_hand_over_mouth', 32: 'face_with_peeking_eye', 33: 'shushing_face', 34: 'thinking', 35: 'saluting_face', 36: 'zipper_mouth_face', 37: 'raised_eyebrow', 38: 'neutral_face', 39: 'expressionless', 40: 'no_mouth', 41: 'dotted_line_face', 42: 'face_in_clouds', 43: 'smirk', 44: 'unamused', 45: 'roll_eyes', 46: 'grimacing', 47: 'face_exhaling', 48: 'lying_face', 49: 'shaking_face', 50: 'relieved', 51: 'pensive', 52: 'sleepy', 53: 'drooling_face', 54: 'sleeping', 55: 'mask', 56: 'face_with_thermometer', 57: 'face_with_head_bandage', 58: 'nauseated_face', 59: 'vomiting_face', 60: 'sneezing_face', 61: 'hot_face', 62: 'cold_face', 63: 'woozy_face', 64: 'dizzy_face', 65: 'face_with_spiral_eyes', 66: 'exploding_head', 67: 'cowboy_hat_face', 68: 'partying_face', 69: 'disguised_face', 70: 'sunglasses', 71: 'nerd_face', 72: 'monocle_face', 73: 'confused', 74: 'face_with_diagonal_mouth', 75: 'worried', 76: 'slightly_frowning_face', 77: 'frowning_face', 78: 'open_mouth', 79: 'hushed', 80: 'astonished', 81: 'flushed', 82: 'pleading_face', 83: 'face_holding_back_tears', 84: 'frowning', 85: 'anguished', 86: 'fearful', 87: 'cold_sweat', 88: 'disappointed_relieved', 89: 'cry', 90: 'sob', 91: 'scream', 92: 'confounded', 93: 'persevere', 94: 'disappointed', 95: 'sweat', 96: 'weary', 97: 'tired_face', 98: 'yawning_face', 99: 'triumph', 100: "['pout', 'rage']", 101: 'angry', 102: 'cursing_face', 103: 'smiling_imp', 104: 'imp', 105: 'skull', 106: 'skull_and_crossbones', 107: "['hankey', 'poop', 'shit']", 108: 'clown_face', 109: 'japanese_ogre', 110: 'japanese_goblin', 111: 'ghost', 112: 'alien', 113: 'space_invader', 114: 'robot', 115: 'smiley_cat', 116: 'smile_cat', 117: 'joy_cat', 118: 'heart_eyes_cat', 119: 'smirk_cat', 120: 'kissing_cat', 121: 'scream_cat', 122: 'crying_cat_face', 123: 'pouting_cat', 124: 'see_no_evil', 125: 'hear_no_evil', 126: 'speak_no_evil', 127: 'love_letter', 128: 'cupid', 129: 'gift_heart', 130: 'sparkling_heart', 131: 'heartpulse', 132: 'heartbeat', 133: 'revolving_hearts', 134: 'two_hearts', 135: 'heart_decoration', 136: 'heavy_heart_exclamation', 137: 'broken_heart', 138: 'heart_on_fire', 139: 'mending_heart', 140: 'heart', 141: 'pink_heart', 142: 'orange_heart', 143: 'yellow_heart', 144: 'green_heart', 145: 'blue_heart', 146: 'light_blue_heart', 147: 'purple_heart', 148: 'brown_heart', 149: 'black_heart', 150: 'grey_heart', 151: 'white_heart', 152: 'kiss', 153: '100', 154: 'anger', 155: "['boom', 'collision']", 156: 'dizzy', 157: 'sweat_drops', 158: 'dash', 159: 'hole', 160: 'speech_balloon', 161: 'eye_speech_bubble', 162: 'left_speech_bubble', 163: 'right_anger_bubble', 164: 'thought_balloon', 165: 'zzz'}
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(

# %%
import json

# Save the idx_to_shortcode dictionary to a JSON file
with open('idx_to_shortcode.json', 'w') as f:
    json.dump(idx_to_shortcode, f, indent=4)

print("idx_to_shortcode dictionary saved to idx_to_shortcode.json")
# Out:
# idx_to_shortcode dictionary saved to idx_to_shortcode.json

# %%
import json, ast, difflib, os
import torch
from torchvision.utils import save_image
# using emoji labels


# -----------------------------
# Config you likely already have
# -----------------------------
# Assumes you’ve already defined/loaded:
#   generator : your trained conditional generator
#   DEVICE    : e.g., torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#   Z_DIM     : latent noise dim used during training
#   (EMBEDDING_DIM is inferred from the model below)

# Example (uncomment / edit for your env):
# DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# generator = YourGeneratorClass(...)
# generator.load_state_dict(torch.load('generator_128.pth', map_location=DEVICE))
# generator.to(DEVICE).eval()
# Z_DIM = 128  # set to your training z-dim

# -----------------------------
# Text → Label-ID mapping utils
# -----------------------------
def _norm(s: str) -> str:
    """normalize user text & shortcodes."""
    s = s.strip().lower()
    if s.startswith(':') and s.endswith(':'):
        s = s[1:-1]
    s = s.replace('-', '_')
    s = ' '.join(s.replace('_', ' ').split())  # collapse spaces/underscores
    return s

def build_name_to_id_map(json_path: str):
    """
    Load idx_to_shortcode.json and build a dict:
      name_variant -> int_id
    Supports single strings or list-like strings in the json values.
    """
    with open(json_path, 'r', encoding='utf-8') as f:
        raw = json.load(f)

    name2id = {}
    for k, v in raw.items():
        idx = int(k)
        candidates = []

        if isinstance(v, list):
            candidates = v
        elif isinstance(v, str):
            # Some entries are stringified lists like "['laughing', 'satisfied']"
            parsed = None
            try:
                parsed = ast.literal_eval(v)
            except Exception:
                parsed = None
            if isinstance(parsed, list):
                candidates = parsed
            else:
                candidates = [v]
        else:
            continue

        for cand in candidates:
            if not isinstance(cand, str):
                continue
            # add multiple variants (underscore and space)
            norm = _norm(cand)
            if norm:
                name2id[norm] = idx
                name2id[norm.replace(' ', '_')] = idx
                name2id[norm.replace(' ', '')] = idx
                # also add colon-wrapped shortcode variant
                name2id[f":{norm.replace(' ', '_')}:"] = idx
    return name2id

def text_to_id(text: str, name2id: dict, topn_fuzzy: int = 3):
    """Exact match first; otherwise fuzzy match on keys."""
    t = _norm(text)
    # quick hits
    for key in (t, t.replace(' ', '_'), t.replace(' ', ''), f":{t.replace(' ', '_')}:"):
        if key in name2id:
            return name2id[key], key, None
    # fuzzy
    keys = list(name2id.keys())
    matches = difflib.get_close_matches(t, keys, n=topn_fuzzy, cutoff=0.6)
    if matches:
        best = matches[0]
        return name2id[best], best, matches
    return None, None, []

# -----------------------------
# Interpolation by text names
# -----------------------------
def interpolate_by_text(
    start_text: str,
    end_text: str,
    idx_json_path: str = "idx_to_shortcode.json",
    steps: int = 30,
    outdir: str = "interpolations",
    outfile_prefix: str = None
):
    os.makedirs(outdir, exist_ok=True)

    name2id = build_name_to_id_map(idx_json_path)

    start_id, start_key, start_suggestions = text_to_id(start_text, name2id)
    end_id, end_key, end_suggestions = text_to_id(end_text, name2id)

    def _suggest_msg(txt, sugg):
        return f" (did you mean: {', '.join(sugg)})" if sugg else ""

    if start_id is None:
        raise ValueError(f"Could not resolve start_text='{start_text}' to a label id."
                         + _suggest_msg(start_text, start_suggestions))
    if end_id is None:
        raise ValueError(f"Could not resolve end_text='{end_text}' to a label id."
                         + _suggest_msg(end_text, end_suggestions))

    print(f"Resolved: '{start_text}' -> id {start_id} ({start_key}), "
          f"'{end_text}' -> id {end_id} ({end_key})")

    # Infer embedding dim directly from the model
    # Assumes generator has attribute .label_embedding similar to nn.Embedding
    embedding_weight = generator.label_embedding.weight
    EMBEDDING_DIM = embedding_weight.shape[1]

    # Prepare noise (same noise across the strip)
    noise = torch.randn(1, Z_DIM, device=DEVICE).repeat(steps, 1)

    # Get embeddings for start & end
    labels_start = torch.tensor([start_id], device=DEVICE)
    labels_end   = torch.tensor([end_id],   device=DEVICE)
    with torch.no_grad():
        embedding_start = generator.label_embedding(labels_start)  # [1, E]
        embedding_end   = generator.label_embedding(labels_end)    # [1, E]

    # Interpolate label embeddings
    interpolated_embeddings = torch.zeros(steps, EMBEDDING_DIM, device=DEVICE)
    for i in range(steps):
        ratio = i / (steps - 1) if steps > 1 else 0.0
        interpolated_embeddings[i] = torch.lerp(embedding_start, embedding_end, ratio)

    # Generate without grads
    with torch.no_grad():
        gan_input = torch.cat((noise, interpolated_embeddings), dim=-1)  # [steps, Z+E]
        gan_input = gan_input.view(-1, Z_DIM + EMBEDDING_DIM, 1, 1)
        # If your generator uses .net as the main forward block:
        if hasattr(generator, "net"):
            interpolated_images = generator.net(gan_input)
        else:
            # or just call forward if your forward expects (z+embed)
            interpolated_images = generator(gan_input)

    # Filename
    if outfile_prefix is None:
        outfile_prefix = f"{start_key}_to_{end_key}".replace(':','').replace(' ','_')
    outpath = os.path.join(outdir, f"interpolation_{outfile_prefix}.png")

    save_image(
        interpolated_images,
        outpath,
        nrow=steps,
        normalize=True
    )
    print(f"Saved: {outpath}")
    return outpath

# -----------------------------
# Example usage
# -----------------------------
if __name__ == "__main__":
    # Edit these to whatever the user types:
    START_TEXT = "rofl"
    END_TEXT   = "money_mouth_face"
    STEPS      = 10

    # Make sure generator, DEVICE, Z_DIM are defined/loaded before this call.
    interpolate_by_text(START_TEXT, END_TEXT, "idx_to_shortcode.json", STEPS)
# Out:
# Resolved: 'rofl' -> id 6 (rofl), 'money_mouth_face' -> id 28 (money mouth face)
# Saved: interpolations/interpolation_rofl_to_money_mouth_face.png

# %%
import torch
from torchvision.utils import save_image

# using emoji labels code

generator.load_state_dict(torch.load('generator_128.pth'))
generator.eval()

TARGET_LABEL_ID_START = 5  # The ID of the starting emoji
TARGET_LABEL_ID_END = 55 # The ID of the ending emoji
INTERPOLATION_STEPS = 30   # Number of images to generate in the sequence

# --- Interpolation Logic ---
print("Generating latent space interpolation...")

# Use the same noise for the whole sequence to see the label's effect
noise = torch.randn(1, Z_DIM, device=DEVICE).repeat(INTERPOLATION_STEPS, 1)

# Get the learned embeddings for the start and end labels from the generator
labels_start = torch.tensor([TARGET_LABEL_ID_START], device=DEVICE)
labels_end = torch.tensor([TARGET_LABEL_ID_END], device=DEVICE)
embedding_start = generator.label_embedding(labels_start)
embedding_end = generator.label_embedding(labels_end)

# Linearly interpolate between the two label embeddings
interpolated_embeddings = torch.zeros(INTERPOLATION_STEPS, EMBEDDING_DIM, device=DEVICE)
for i in range(INTERPOLATION_STEPS):
    ratio = i / (INTERPOLATION_STEPS - 1)
    interpolated_embeddings[i] = torch.lerp(embedding_start, embedding_end, ratio)

# Generate the sequence without calculating gradients
with torch.no_grad():
    # Manually combine noise and the interpolated embeddings
    gan_input = torch.cat((noise, interpolated_embeddings), -1).view(-1, Z_DIM + EMBEDDING_DIM, 1, 1)
    # Pass through the generator's network
    interpolated_images = generator.net(gan_input)

# Save the resulting image strip
save_image(
    interpolated_images,
    f"interpolation_from_{TARGET_LABEL_ID_START}_to_{TARGET_LABEL_ID_END}.png",
    nrow=INTERPOLATION_STEPS,
    normalize=True
)

print(f"Saved interpolation image strip.")
# Out:
# Generating latent space interpolation...
# Saved interpolation image strip.

# %%
# using label id
import torch
from torchvision.utils import save_image

generator.load_state_dict(torch.load('generator_128.pth'))
generator.eval()
# --- Configuration ---
TARGET_LABEL_ID = 5 # The ID of the emoji you want to see variations of
NUM_SAMPLES = 16     # The number of images to generate (should be a perfect square, e.g., 9, 16, 25)

# --- Diversity Generation Logic ---
print(f"Generating {NUM_SAMPLES} diverse samples for label ID: {TARGET_LABEL_ID}...")

# Create different noise for each sample
noise = torch.randn(NUM_SAMPLES, Z_DIM, device=DEVICE)
# Use the same label for all samples
labels = torch.full((NUM_SAMPLES,), TARGET_LABEL_ID, dtype=torch.long, device=DEVICE)

# Generate images
with torch.no_grad():
    generated_images = generator(noise, labels)

# Save the resulting image grid
save_image(
    generated_images,
    f"diversity_for_label_{TARGET_LABEL_ID}.png",
    nrow=int(NUM_SAMPLES**0.5), # Arrange in a square grid
    normalize=True
)

print(f"Saved visual diversity grid.")

# %%
# using label name
import os
import torch
from torchvision.utils import save_image

# If the helpers are in another module, import them instead:
# from your_helpers import build_name_to_id_map, text_to_id

def generate_diversity_by_text_or_id(
    target,                 # e.g. 5 or "sweat_smile" or ":sweat_smile:"
    num_samples=1,
    idx_json_path="idx_to_shortcode.json",
    outdir="diversity"
):
    """
    Generate a grid of samples for a single label specified by text or id.
    Reuses the generator(noise, labels) interface when available; otherwise
    falls back to concatenating noise+embedding and calling generator.net.
    """
    os.makedirs(outdir, exist_ok=True)

    # Resolve label id ---------------------------------------------------------
    if isinstance(target, int):
        target_id = target
        resolved_key = str(target_id)
    else:
        # Build mapping and resolve the text
        name2id = build_name_to_id_map(idx_json_path)
        target_id, key_used, suggestions = text_to_id(str(target), name2id)
        if target_id is None:
            msg = f"Could not resolve '{target}' to a label id."
            if suggestions:
                msg += f" Did you mean: {', '.join(suggestions)} ?"
            raise ValueError(msg)
        resolved_key = key_used

    print(f"Generating {num_samples} samples for label id {target_id} ({resolved_key})")

    # Noise + labels -----------------------------------------------------------
    noise  = torch.randn(num_samples, Z_DIM, device=DEVICE)
    labels = torch.full((num_samples,), target_id, dtype=torch.long, device=DEVICE)

    # Generate -----------------------------------------------------------------
    with torch.no_grad():
        try:
            # Preferred path: your model supports (noise, labels)
            generated_images = generator(noise, labels)
        except TypeError:
            # Fallback: manually concat noise + label embedding and call main net
            emb = generator.label_embedding(labels)                     # [N, E]
            gan_in = torch.cat([noise, emb], dim=1).view(num_samples, -1, 1, 1)
            if hasattr(generator, "net"):
                generated_images = generator.net(gan_in)
            else:
                generated_images = generator(gan_in)  # if forward accepts concatenated input

    # Save grid ----------------------------------------------------------------
    nrow = int(num_samples ** 0.5)
    out_path = os.path.join(outdir, f"diversity_{resolved_key}_{target_id}.png")
    save_image(generated_images, out_path, nrow=nrow, normalize=True)
    print(f"Saved visual diversity grid to {out_path}")
    return out_path


# ----------------- Example usage (replace to your needs) -----------------
# Either text:
generate_diversity_by_text_or_id("smirk", idx_json_path="idx_to_shortcode.json")

# Or raw id (old behavior):
# generate_diversity_by_text_or_id(5, num_samples=16, idx_json_path="idx_to_shortcode.json")
# Out:
# Generating 1 samples for label id 43 (smirk)
# Saved visual diversity grid to diversity/diversity_smirk_43.png
# 'diversity/diversity_smirk_43.png'
